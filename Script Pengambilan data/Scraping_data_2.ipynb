# %%
# !pip install overpy pandas geopy

# %%
from geopy.geocoders import Nominatim
import pandas as pd
import time

wisata_aceh_list = [
    "Gunung Seulawah", "Gunung Geureudong", "Danau Laut Tawar", "Taman Nasional Gunung Leuser",
    "Masjid Raya Baiturrahman", "Pantai Lampuuk", "Pantai Lhoknga", "Museum Tsunami Aceh",
    "Monumen Kapal PLTD Apung", "Taman Sari Gunongan", "Pulau Weh", "Air Terjun Suhom",
    "Bukit Indah Simpang Tiga", "Pantai Kuala Merisi", "Museum Aceh", "Alun-Alun Banda Aceh",
    "Istana Kesultanan Aceh", "Pasar Aceh", "Kebun Binatang Banda Aceh", "Taman Pendidikan Taman Siswa",
    "Waterboom Kuala Langsa", "Rumah Adat Aceh", "Pantai Pasir Putih", "Pulau Banyak",
    "Pantai Melur", "Candi Muara Takus", "Taman Wisata Pantai Ujong Blang", "Pulau Bunta",
    "Lampion Garden Banda Aceh", "Pantai Ujong Kareung", "Bukit Lawang", "Air Terjun Blang Kolam",
    "Museum Kota Banda Aceh", "Masjid Al-Makmur Paya Keutapang", "Pantai Lhok Mee",
    "Pantai Kuala Cangkoy", "Air Terjun Ie Suak", "Monumen Tsunami Aceh",
    "Taman Wisata Alam Laut Pulau Banyak", "Gunung Peunaron", "Museum Negeri Aceh",
    "Pantai Teunom", "Pantai Tapak Gajah", "Danau Aneuk Laot", "Pulau Klah",
    "Benteng Indra Purba", "Pantai Ulee Lheu", "Taman Hutan Raya Pocut Meurah Intan",
    "Pantai Lhok Bubon", "Wisata Kuliner Aceh"
]

geolocator = Nominatim(user_agent="wisata_aceh_geocoder")
results = []

for nama in wisata_aceh_list:
    try:
        query = f"{nama}, Aceh, Indonesia"
        location = geolocator.geocode(query, exactly_one=True, addressdetails=True)
        if location:
            addr = location.raw.get('address', {})
            results.append({
                "nama_wisata": nama,
                "latitude": location.latitude,
                "longitude": location.longitude,
                "alamat": location.address,
                "provinsi": addr.get('state', ''),
                "kota_kabupaten": addr.get('city', '') or addr.get('county', '') or addr.get('region', '')
            })
            print(f"✓ Ditemukan: {nama}")
        else:
            results.append({
                "nama_wisata": nama,
                "latitude": None,
                "longitude": None,
                "alamat": "Not Found",
                "provinsi": "",
                "kota_kabupaten": ""
            })
            print(f"✗ Tidak ditemukan: {nama}")
    except Exception as e:
        results.append({
            "nama_wisata": nama,
            "latitude": None,
            "longitude": None,
            "alamat": f"Error: {e}",
            "provinsi": "",
            "kota_kabupaten": ""
        })
        print(f"⚠️ Error: {nama} - {e}")
    time.sleep(1)

df = pd.DataFrame(results)
df.to_csv("wisata_aceh_geocoding_only.csv", index=False)
print("✅ Data wisata Aceh berhasil disimpan ke 'wisata_aceh_geocoding_only.csv'")
# Out:
# ✓ Ditemukan: Gunung Seulawah
# ✓ Ditemukan: Gunung Geureudong
# ✓ Ditemukan: Danau Laut Tawar
# ✓ Ditemukan: Taman Nasional Gunung Leuser
# ✓ Ditemukan: Masjid Raya Baiturrahman
# ✓ Ditemukan: Pantai Lampuuk
# ✓ Ditemukan: Pantai Lhoknga
# ✓ Ditemukan: Museum Tsunami Aceh
# ✗ Tidak ditemukan: Monumen Kapal PLTD Apung
# ✗ Tidak ditemukan: Taman Sari Gunongan
# ✓ Ditemukan: Pulau Weh
# ✗ Tidak ditemukan: Air Terjun Suhom
# ✗ Tidak ditemukan: Bukit Indah Simpang Tiga
# ✗ Tidak ditemukan: Pantai Kuala Merisi
# ✓ Ditemukan: Museum Aceh
# ✗ Tidak ditemukan: Alun-Alun Banda Aceh
# ✗ Tidak ditemukan: Istana Kesultanan Aceh
# ✓ Ditemukan: Pasar Aceh
# ✗ Tidak ditemukan: Kebun Binatang Banda Aceh
# ✗ Tidak ditemukan: Taman Pendidikan Taman Siswa
# ✗ Tidak ditemukan: Waterboom Kuala Langsa
# ...

# %%
from geopy.geocoders import Nominatim
import pandas as pd
import time

# List wisata Sumatera Utara (50+ tempat)
wisata_sumut_list = [
    "Danau Toba", "Pulau Samosir", "Air Terjun Sipiso-piso", "Bukit Lawang", "Gunung Sinabung",
    "Museum Negeri Propinsi Sumatera Utara", "Istana Maimun", "Masjid Raya Medan",
    "Taman Nasional Gunung Leuser", "Air Terjun Sikulikap", "Pantai Cermin", "Danau Lau Kawar",
    "Pantai Bagan Asahan", "Air Terjun Dua Warna", "Batu Kursi Samosir", "Pulau Putri Samosir",
    "Bukit Indah Sibolangit", "Makam Kesultanan Deli", "Vihara Gunung Timur", "Taman Cadika Medan",
    "Masjid Tua Tanjung Balai", "Air Terjun Sipoholon", "Pantai Indah Berhala", "Kebun Binatang Medan",
    "Pulau Berhala", "Taman Hutan Raya Bukit Barisan", "Candi Bahal", "Rumah Adat Batak Toba",
    "Bukit Barisan Selatan", "Gunung Sibayak", "Danau Linting", "Air Terjun Situmurun",
    "Pantai Muara Labuhan", "Rumah Bolon Simalungun", "Taman Nasional Batang Gadis", "Gunung Pusuk Buhit",
    "Bukit Lawang Jungle Trek", "Air Terjun Sampuran", "Monumen Perjuangan Medan", "Pulau Pandang",
    "Pantai Tanjung Tiram", "Rumah Adat Karo", "Desa Wisata Simalungun", "Taman Pendidikan Sumatera Utara",
    "Kebun Teh Sidamanik", "Air Terjun Pemandian Air Panas Lau Debuk-debuk"
]

geolocator = Nominatim(user_agent="wisata_sumut_geocoder")
results = []

for nama in wisata_sumut_list:
    try:
        query = f"{nama}, Sumatera Utara, Indonesia"
        location = geolocator.geocode(query, exactly_one=True, addressdetails=True)
        if location:
            addr = location.raw.get('address', {})
            results.append({
                "nama_wisata": nama,
                "latitude": location.latitude,
                "longitude": location.longitude,
                "alamat": location.address,
                "provinsi": addr.get('state', ''),
                "kota_kabupaten": addr.get('city', '') or addr.get('county', '') or addr.get('region', '')
            })
            print(f"✓ Ditemukan: {nama}")
        else:
            results.append({
                "nama_wisata": nama,
                "latitude": None,
                "longitude": None,
                "alamat": "Not Found",
                "provinsi": "",
                "kota_kabupaten": ""
            })
            print(f"✗ Tidak ditemukan: {nama}")
    except Exception as e:
        results.append({
            "nama_wisata": nama,
            "latitude": None,
            "longitude": None,
            "alamat": f"Error: {e}",
            "provinsi": "",
            "kota_kabupaten": ""
        })
        print(f"⚠️ Error: {nama} - {e}")
    time.sleep(1)

df = pd.DataFrame(results)
df.to_csv("wisata_sumatera_utara_geocoding.csv", index=False)
print("✅ Data wisata Sumatera Utara berhasil disimpan ke 'wisata_sumatera_utara_geocoding.csv'")
# Out:
# ✓ Ditemukan: Danau Toba
# ✓ Ditemukan: Pulau Samosir
# ✗ Tidak ditemukan: Air Terjun Sipiso-piso
# ✓ Ditemukan: Bukit Lawang
# ✓ Ditemukan: Gunung Sinabung
# ✗ Tidak ditemukan: Museum Negeri Propinsi Sumatera Utara
# ✓ Ditemukan: Istana Maimun
# ✓ Ditemukan: Masjid Raya Medan
# ✗ Tidak ditemukan: Taman Nasional Gunung Leuser
# ✗ Tidak ditemukan: Air Terjun Sikulikap
# ✓ Ditemukan: Pantai Cermin
# ✓ Ditemukan: Danau Lau Kawar
# ✗ Tidak ditemukan: Pantai Bagan Asahan
# ✓ Ditemukan: Air Terjun Dua Warna
# ✗ Tidak ditemukan: Batu Kursi Samosir
# ✗ Tidak ditemukan: Pulau Putri Samosir
# ✗ Tidak ditemukan: Bukit Indah Sibolangit
# ✗ Tidak ditemukan: Makam Kesultanan Deli
# ✓ Ditemukan: Vihara Gunung Timur
# ✓ Ditemukan: Taman Cadika Medan
# ✗ Tidak ditemukan: Masjid Tua Tanjung Balai
# ✗ Tidak ditemukan: Air Terjun Sipoholon
# ✗ Tidak ditemukan: Pantai Indah Berhala
# ✓ Ditemukan: Kebun Binatang Medan
# ✓ Ditemukan: Pulau Berhala
# ✗ Tidak ditemukan: Taman Hutan Raya Bukit Barisan
# ...

# %%
wisata_sumbar_list = [
    "Danau Maninjau", "Danau Singkarak", "Jam Gadang Bukittinggi", "Lembah Harau",
    "Istana Pagaruyung", "Ngarai Sianok", "Pantai Padang", "Air Terjun Lembah Anai",
    "Museum Adityawarman", "Bukit Tinggi", "Air Terjun Sarasah Aia", "Pantai Air Manis",
    "Rumah Gadang", "Goa Jepang Bukittinggi", "Taman Panorama", "Pantai Carocok Painan",
    "Danau Talang", "Masjid Raya Sumatera Barat", "Bukit Langkisau", "Air Terjun Tuo",
    "Puncak Lawang", "Istano Basa Pagaruyuang", "Air Terjun Lubuak Bonta", "Taman Wisata Alam Mandeh",
    "Lubuk Sikaping", "Danau Diateh", "Bukit Barisan Selatan", "Museum Rumah Kelahiran Bung Hatta",
    "Puncak Gurun", "Air Terjun Bayang Sani", "Pantai Nirwana Padang", "Jembatan Siti Nurbaya",
    "Pantai Gandoriah", "Air Terjun Sarasah Cubadak", "Kawasan Wisata Sikabu", "Bukit Randang",
    "Museum Adat Minangkabau", "Air Terjun Tabik", "Pantai Taluk Bayur", "Danau Singkarak Pulau Sikuai",
    "Rumah Gadang Baanjuang", "Kawasan Wisata Puncak Lawang", "Air Terjun Lubuk Hitam",
    "Pantai Muaro Lasak", "Danau Talang Suliki", "Bukit Malintang", "Taman Wisata Alam Batang Anai",
    "Air Terjun Lembah Anai", "Gunung Tandikat", "Danau Singkarak Pulau Sikuai"
]

geolocator = Nominatim(user_agent="wisata_sumba_geocoder")
results = []

for nama in wisata_sumbar_list:
    try:
        query = f"{nama}, Sumatera Barat, Indonesia"
        location = geolocator.geocode(query, exactly_one=True, addressdetails=True)
        if location:
            addr = location.raw.get('address', {})
            results.append({
                "nama_wisata": nama,
                "latitude": location.latitude,
                "longitude": location.longitude,
                "alamat": location.address,
                "provinsi": addr.get('state', ''),
                "kota_kabupaten": addr.get('city', '') or addr.get('county', '') or addr.get('region', '')
            })
            print(f"✓ Ditemukan: {nama}")
        else:
            results.append({
                "nama_wisata": nama,
                "latitude": None,
                "longitude": None,
                "alamat": "Not Found",
                "provinsi": "",
                "kota_kabupaten": ""
            })
            print(f"✗ Tidak ditemukan: {nama}")
    except Exception as e:
        results.append({
            "nama_wisata": nama,
            "latitude": None,
            "longitude": None,
            "alamat": f"Error: {e}",
            "provinsi": "",
            "kota_kabupaten": ""
        })
        print(f"⚠️ Error: {nama} - {e}")
    time.sleep(1)

df = pd.DataFrame(results)
df.to_csv("wisata_sumatera_barat_geocoding.csv", index=False)
print("✅ Data wisata Sumatera Utara berhasil disimpan ke 'wisata_sumatera_barat_geocoding.csv'")
# Out:
# ✓ Ditemukan: Danau Maninjau
# ✓ Ditemukan: Danau Singkarak
# ✓ Ditemukan: Jam Gadang Bukittinggi
# ✓ Ditemukan: Lembah Harau
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=Istana+Pagaruyung%2C+Sumatera+Barat%2C+Indonesia&format=json&limit=1&addressdetails=1
# ✓ Ditemukan: Istana Pagaruyung
# ✓ Ditemukan: Ngarai Sianok
# ✓ Ditemukan: Pantai Padang
# ✗ Tidak ditemukan: Air Terjun Lembah Anai
# ✓ Ditemukan: Museum Adityawarman
# ✓ Ditemukan: Bukit Tinggi
# ✗ Tidak ditemukan: Air Terjun Sarasah Aia
# ✓ Ditemukan: Pantai Air Manis
# ✓ Ditemukan: Rumah Gadang
# ✗ Tidak ditemukan: Goa Jepang Bukittinggi
# ✓ Ditemukan: Taman Panorama
# ✗ Tidak ditemukan: Pantai Carocok Painan
# ✓ Ditemukan: Danau Talang
# ✓ Ditemukan: Masjid Raya Sumatera Barat
# ...

# %%
from geopy.geocoders import Nominatim
import pandas as pd
import time

# List wisata Riau (50+ tempat)
wisata_riau_list = [
    "Danau Raja", "Cagar Alam Giam Siak Kecil", "Sungai Kampar", "Pantai Rupat",
    "Taman Nasional Tesso Nilo", "Danau Tajwid", "Istana Siak Sri Indrapura", "Masjid Sultan Syarif Qasim II",
    "Bukit Naang", "Danau Limbungan", "Air Terjun Toroan", "Pulau Tebing Tinggi",
    "Candi Muara Takus", "Benteng Kerajaan Indragiri", "Pantai Teluk Rhu", "Desa Wisata Teluk Meranti",
    "Bukit Batu", "Danau Maninjau Riau", "Pantai Selat Baru", "Taman Wisata Alam Bukit Betabuh",
    "Air Terjun Simpang Kanan", "Candi Muara Takus", "Kawasan Wisata Lubuk Jantan", "Pulau Beting Aceh",
    "Bukit Batu Regency Park", "Museum Sang Nila Utama", "Pulau Padang", "Danau Enok",
    "Masjid Raya An-Nur Pekanbaru", "Sungai Siak", "Pantai Indah Batam", "Air Terjun Tujuh Tingkat",
    "Bukit Tiga Puluh National Park", "Rumah Adat Melayu Riau", "Taman Nasional Bukit Tiga Puluh", "Danau Lanjau",
    "Taman Rekreasi Alam Mayang", "Air Terjun Langkai", "Sungai Kampar Kanan", "Pantai Teluk Makmur",
    "Bukit Barisan", "Air Terjun Batang Kapas", "Kampung Melayu Pelalawan", "Taman Budaya Riau",
    "Bukit Naang Waterfall", "Danau Koto Panjang", "Pantai Putri Tujuh", "Monumen Perjuangan Riau",
    "Pulau Rupat", "Museum Melayu Riau"
]

geolocator = Nominatim(user_agent="wisata_riau_geocoder")
results = []

for nama in wisata_riau_list:
    try:
        query = f"{nama}, Riau, Indonesia"
        location = geolocator.geocode(query, exactly_one=True, addressdetails=True)
        if location:
            addr = location.raw.get('address', {})
            results.append({
                "nama_wisata": nama,
                "latitude": location.latitude,
                "longitude": location.longitude,
                "alamat": location.address,
                "provinsi": addr.get('state', ''),
                "kota_kabupaten": addr.get('city', '') or addr.get('county', '') or addr.get('region', '')
            })
            print(f"✓ Ditemukan: {nama}")
        else:
            results.append({
                "nama_wisata": nama,
                "latitude": None,
                "longitude": None,
                "alamat": "Not Found",
                "provinsi": "",
                "kota_kabupaten": ""
            })
            print(f"✗ Tidak ditemukan: {nama}")
    except Exception as e:
        results.append({
            "nama_wisata": nama,
            "latitude": None,
            "longitude": None,
            "alamat": f"Error: {e}",
            "provinsi": "",
            "kota_kabupaten": ""
        })
        print(f"⚠️ Error: {nama} - {e}")
    time.sleep(1)

df = pd.DataFrame(results)
df.to_csv("wisata_riau_geocoding.csv", index=False)
print("✅ Data wisata Riau berhasil disimpan ke 'wisata_riau_geocoding.csv'")
# Out:
# ✓ Ditemukan: Danau Raja
# ✗ Tidak ditemukan: Cagar Alam Giam Siak Kecil
# ✓ Ditemukan: Sungai Kampar
# ✗ Tidak ditemukan: Pantai Rupat
# ✓ Ditemukan: Taman Nasional Tesso Nilo
# ✓ Ditemukan: Danau Tajwid
# ✓ Ditemukan: Istana Siak Sri Indrapura
# ✗ Tidak ditemukan: Masjid Sultan Syarif Qasim II
# ✗ Tidak ditemukan: Bukit Naang
# ✗ Tidak ditemukan: Danau Limbungan
# ✗ Tidak ditemukan: Air Terjun Toroan
# ✓ Ditemukan: Pulau Tebing Tinggi
# ✓ Ditemukan: Candi Muara Takus
# ✗ Tidak ditemukan: Benteng Kerajaan Indragiri
# ✗ Tidak ditemukan: Pantai Teluk Rhu
# ✗ Tidak ditemukan: Desa Wisata Teluk Meranti
# ✓ Ditemukan: Bukit Batu
# ✗ Tidak ditemukan: Danau Maninjau Riau
# ✓ Ditemukan: Pantai Selat Baru
# ✗ Tidak ditemukan: Taman Wisata Alam Bukit Betabuh
# ✗ Tidak ditemukan: Air Terjun Simpang Kanan
# ✓ Ditemukan: Candi Muara Takus
# ✗ Tidak ditemukan: Kawasan Wisata Lubuk Jantan
# ✗ Tidak ditemukan: Pulau Beting Aceh
# ✗ Tidak ditemukan: Bukit Batu Regency Park
# ...

# %%
from geopy.geocoders import Nominatim
import pandas as pd
import time

wisata_kepri_list = [
    "Pulau Bintan", "Pulau Batam", "Pantai Trikora", "Pantai Tanjung Pinggir", "Pantai Pasir Panjang",
    "Pulau Penyengat", "Masjid Raya Sultan Riau", "Pulau Nikoi", "Pantai Lagoi", "Danau Biru Bintan",
    "Taman Wisata Gurun Pasir Bintan", "Pulau Galang", "Pantai Melur", "Pantai Nongsa", "Kawasan Industri Barelang",
    "Jembatan Barelang", "Pulau Karimun", "Pulau Kundur", "Pantai Kelong", "Pantai Sekilak",
    "Bukit Sengkuang", "Pulau Buluh", "Museum Sultan Riau", "Pantai Mapur", "Taman Nasional Karimun Jawa",
    "Pulau Jemur", "Pantai Tanjung Berakit", "Pulau Pasir", "Air Terjun Temurun", "Pulau Mantang",
    "Bukit Arai", "Pantai Lagoi Bay", "Pantai Lagoi Bintan", "Desa Wisata Ekang", "Pulau Lengkuas",
    "Taman Rekreasi Pantai Lagoi", "Pulau Babi Besar", "Pulau Trikora", "Pulau Beralas Pasir", "Pantai Pasir Panjang Lagoi",
    "Pulau Payung", "Pulau Pongkar", "Pantai Sekilak", "Taman Buru Sungai Mas", "Pantai Tanjung Uban",
    "Pulau Sambu", "Pantai Sekupang", "Pulau Tering", "Bukit Daik", "Pantai Tanjung Pesona"
]

geolocator = Nominatim(user_agent="wisata_kepri_geocoder")
results = []

for nama in wisata_kepri_list:
    try:
        query = f"{nama}, Kepulauan Riau, Indonesia"
        location = geolocator.geocode(query, exactly_one=True, addressdetails=True)
        if location:
            addr = location.raw.get('address', {})
            results.append({
                "nama_wisata": nama,
                "latitude": location.latitude,
                "longitude": location.longitude,
                "alamat": location.address,
                "provinsi": addr.get('state', ''),
                "kota_kabupaten": addr.get('city', '') or addr.get('county', '') or addr.get('region', '')
            })
            print(f"✓ Ditemukan: {nama}")
        else:
            results.append({
                "nama_wisata": nama,
                "latitude": None,
                "longitude": None,
                "alamat": "Not Found",
                "provinsi": "",
                "kota_kabupaten": ""
            })
            print(f"✗ Tidak ditemukan: {nama}")
    except Exception as e:
        results.append({
            "nama_wisata": nama,
            "latitude": None,
            "longitude": None,
            "alamat": f"Error: {e}",
            "provinsi": "",
            "kota_kabupaten": ""
        })
        print(f"⚠️ Error: {nama} - {e}")
    time.sleep(1)

df = pd.DataFrame(results)
df.to_csv("wisata_kepulauan_riau_geocoding.csv", index=False)
print("✅ Data wisata Kepulauan Riau berhasil disimpan ke 'wisata_kepulauan_riau_geocoding.csv'")
# Out:
# ✓ Ditemukan: Pulau Bintan
# ✓ Ditemukan: Pulau Batam
# ✗ Tidak ditemukan: Pantai Trikora
# ✗ Tidak ditemukan: Pantai Tanjung Pinggir
# ✗ Tidak ditemukan: Pantai Pasir Panjang
# ✓ Ditemukan: Pulau Penyengat
# ✓ Ditemukan: Masjid Raya Sultan Riau
# ✓ Ditemukan: Pulau Nikoi
# ✗ Tidak ditemukan: Pantai Lagoi
# ✗ Tidak ditemukan: Danau Biru Bintan
# ✗ Tidak ditemukan: Taman Wisata Gurun Pasir Bintan
# ✓ Ditemukan: Pulau Galang
# ✗ Tidak ditemukan: Pantai Melur
# ✗ Tidak ditemukan: Pantai Nongsa
# ✗ Tidak ditemukan: Kawasan Industri Barelang
# ✓ Ditemukan: Jembatan Barelang
# ✓ Ditemukan: Pulau Karimun
# ✓ Ditemukan: Pulau Kundur
# ✗ Tidak ditemukan: Pantai Kelong
# ✗ Tidak ditemukan: Pantai Sekilak
# ✗ Tidak ditemukan: Bukit Sengkuang
# ✓ Ditemukan: Pulau Buluh
# ✓ Ditemukan: Museum Sultan Riau
# ✗ Tidak ditemukan: Pantai Mapur
# ✗ Tidak ditemukan: Taman Nasional Karimun Jawa
# ✗ Tidak ditemukan: Pulau Jemur
# ✗ Tidak ditemukan: Pantai Tanjung Berakit
# ✓ Ditemukan: Pulau Pasir
# ...

# %%
from geopy.geocoders import Nominatim
import pandas as pd
import time

wisata_jambi_list = [
    "Kerinci Seblat National Park", "Danau Kerinci", "Air Terjun Sigerincing", "Danau Gunung Tujuh",
    "Bukit 30", "Candi Muaro Jambi", "Taman Nasional Berbak", "Danau Sipin", "Bukit Kayangan",
    "Pantai Sepanjang", "Gunung Kerinci", "Air Terjun Rantau Pandan", "Taman Rimba Mayang",
    "Air Terjun Merangin", "Pantai Teluk Sepang", "Danau Kaco", "Desa Wisata Sungai Gelam",
    "Gunung Tujuh", "Air Terjun Sigerincing", "Bukit Peninjau", "Sungai Batanghari", "Pulau Berhala",
    "Air Terjun Pancuran Rayo", "Rumah Adat Melayu Jambi", "Taman Hutan Raya Sultan Thaha Syaifuddin",
    "Pantai Tanjung Sepat", "Air Terjun Putri Malu", "Bukit Sigerincing", "Pantai Pura", "Danau Sipin",
    "Kampung Melayu Sigerincing", "Air Terjun Merangin", "Pantai Muaro Bungo", "Danau Kerinci",
    "Bukit Tanjung Jabung", "Air Terjun Batang Merangin", "Pantai Sepanjang", "Museum Negeri Jambi",
    "Candi Muaro Jambi", "Gunung Kerinci", "Bukit Sigerincing", "Air Terjun Koto Tinggi", "Pantai Tanjung Sepat",
    "Air Terjun Sigerincing", "Danau Kaco", "Taman Nasional Berbak", "Pulau Karan", "Pantai Teluk Sepang",
    "Bukit Kayangan", "Air Terjun Batang Merangin"
]

geolocator = Nominatim(user_agent="wisata_jambi_geocoder")
results = []

for nama in wisata_jambi_list:
    try:
        query = f"{nama}, Jambi, Indonesia"
        location = geolocator.geocode(query, exactly_one=True, addressdetails=True)
        if location:
            addr = location.raw.get('address', {})
            results.append({
                "nama_wisata": nama,
                "latitude": location.latitude,
                "longitude": location.longitude,
                "alamat": location.address,
                "provinsi": addr.get('state', ''),
                "kota_kabupaten": addr.get('city', '') or addr.get('county', '') or addr.get('region', '')
            })
            print(f"✓ Ditemukan: {nama}")
        else:
            results.append({
                "nama_wisata": nama,
                "latitude": None,
                "longitude": None,
                "alamat": "Not Found",
                "provinsi": "",
                "kota_kabupaten": ""
            })
            print(f"✗ Tidak ditemukan: {nama}")
    except Exception as e:
        results.append({
            "nama_wisata": nama,
            "latitude": None,
            "longitude": None,
            "alamat": f"Error: {e}",
            "provinsi": "",
            "kota_kabupaten": ""
        })
        print(f"⚠️ Error: {nama} - {e}")
    time.sleep(1)

df = pd.DataFrame(results)
df.to_csv("wisata_jambi_geocoding.csv", index=False)
print("✅ Data wisata Jambi berhasil disimpan ke 'wisata_jambi_geocoding.csv'")
# Out:
# ✓ Ditemukan: Kerinci Seblat National Park
# ✓ Ditemukan: Danau Kerinci
# ✗ Tidak ditemukan: Air Terjun Sigerincing
# ✓ Ditemukan: Danau Gunung Tujuh
# ✓ Ditemukan: Bukit 30
# ✓ Ditemukan: Candi Muaro Jambi
# ✓ Ditemukan: Taman Nasional Berbak
# ✓ Ditemukan: Danau Sipin
# ✗ Tidak ditemukan: Bukit Kayangan
# ✗ Tidak ditemukan: Pantai Sepanjang
# ✓ Ditemukan: Gunung Kerinci
# ✗ Tidak ditemukan: Air Terjun Rantau Pandan
# ✗ Tidak ditemukan: Taman Rimba Mayang
# ✗ Tidak ditemukan: Air Terjun Merangin
# ✗ Tidak ditemukan: Pantai Teluk Sepang
# ✗ Tidak ditemukan: Danau Kaco
# ✗ Tidak ditemukan: Desa Wisata Sungai Gelam
# ✓ Ditemukan: Gunung Tujuh
# ✗ Tidak ditemukan: Air Terjun Sigerincing
# ✗ Tidak ditemukan: Bukit Peninjau
# ✓ Ditemukan: Sungai Batanghari
# ✓ Ditemukan: Pulau Berhala
# ✗ Tidak ditemukan: Air Terjun Pancuran Rayo
# ✗ Tidak ditemukan: Rumah Adat Melayu Jambi
# ✓ Ditemukan: Taman Hutan Raya Sultan Thaha Syaifuddin
# ✗ Tidak ditemukan: Pantai Tanjung Sepat
# ...

# %%
from geopy.geocoders import Nominatim
import pandas as pd
import time

wisata_bengkulu_list = [
    "Pantai Panjang", "Benteng Marlborough", "Danau Dendam Tak Sudah", "Pulau Tikus",
    "Rumah Pengasingan Bung Karno", "Air Terjun Curup", "Bukit Kaba", "Pantai Tapak Paderi",
    "Pantai Jakat", "Taman Nasional Kerinci Seblat", "Air Terjun Air Rami", "Danau Mas Harun Bastari",
    "Air Terjun Curup Embun", "Desa Wisata Pematang Gajah", "Pantai Jenggalu", "Gunung Kaba",
    "Pulau Enggano", "Museum Bengkulu", "Pantai Tanjung Kerasak", "Danau Mas Harun Bastari",
    "Air Terjun Batu Mandi", "Pantai Melur", "Benteng Kuto Besak", "Danau Kembar",
    "Bukit Barisan", "Pulau Tikus", "Pantai Mutun", "Taman Wisata Alam Padang Sugihan",
    "Bukit Kaba", "Air Terjun Karang Anyar", "Pulau Baai", "Pantai Panjang Bengkulu",
    "Bukit Kaba", "Danau Dendam Tak Sudah", "Pantai Jakat", "Benteng Marlborough",
    "Air Terjun Curup", "Pulau Enggano", "Rumah Pengasingan Bung Karno", "Pantai Tapak Paderi",
    "Pantai Mutun", "Danau Mas Harun Bastari", "Air Terjun Curup Embun", "Bukit Kaba",
    "Pantai Jenggalu", "Pulau Tikus", "Museum Bengkulu", "Pantai Tanjung Kerasak",
    "Air Terjun Batu Mandi", "Danau Kembar"
]

geolocator = Nominatim(user_agent="wisata_bengkulu_geocoder")
results = []

for nama in wisata_bengkulu_list:
    try:
        query = f"{nama}, Bengkulu, Indonesia"
        location = geolocator.geocode(query, exactly_one=True, addressdetails=True)
        if location:
            addr = location.raw.get('address', {})
            results.append({
                "nama_wisata": nama,
                "latitude": location.latitude,
                "longitude": location.longitude,
                "alamat": location.address,
                "provinsi": addr.get('state', ''),
                "kota_kabupaten": addr.get('city', '') or addr.get('county', '') or addr.get('region', '')
            })
            print(f"✓ Ditemukan: {nama}")
        else:
            results.append({
                "nama_wisata": nama,
                "latitude": None,
                "longitude": None,
                "alamat": "Not Found",
                "provinsi": "",
                "kota_kabupaten": ""
            })
            print(f"✗ Tidak ditemukan: {nama}")
    except Exception as e:
        results.append({
            "nama_wisata": nama,
            "latitude": None,
            "longitude": None,
            "alamat": f"Error: {e}",
            "provinsi": "",
            "kota_kabupaten": ""
        })
        print(f"⚠️ Error: {nama} - {e}")
    time.sleep(1)

df = pd.DataFrame(results)
df.to_csv("wisata_bengkulu_geocoding.csv", index=False)
print("✅ Data wisata Bengkulu berhasil disimpan ke 'wisata_bengkulu_geocoding.csv'")
# Out:
# ✓ Ditemukan: Pantai Panjang
# ✓ Ditemukan: Benteng Marlborough
# ✓ Ditemukan: Danau Dendam Tak Sudah
# ✓ Ditemukan: Pulau Tikus
# ✗ Tidak ditemukan: Rumah Pengasingan Bung Karno
# ✗ Tidak ditemukan: Air Terjun Curup
# ✓ Ditemukan: Bukit Kaba
# ✗ Tidak ditemukan: Pantai Tapak Paderi
# ✓ Ditemukan: Pantai Jakat
# ✗ Tidak ditemukan: Taman Nasional Kerinci Seblat
# ✗ Tidak ditemukan: Air Terjun Air Rami
# ✗ Tidak ditemukan: Danau Mas Harun Bastari
# ✗ Tidak ditemukan: Air Terjun Curup Embun
# ✗ Tidak ditemukan: Desa Wisata Pematang Gajah
# ✗ Tidak ditemukan: Pantai Jenggalu
# ✓ Ditemukan: Gunung Kaba
# ✓ Ditemukan: Pulau Enggano
# ✓ Ditemukan: Museum Bengkulu
# ✗ Tidak ditemukan: Pantai Tanjung Kerasak
# ✗ Tidak ditemukan: Danau Mas Harun Bastari
# ✗ Tidak ditemukan: Air Terjun Batu Mandi
# ✗ Tidak ditemukan: Pantai Melur
# ✗ Tidak ditemukan: Benteng Kuto Besak
# ✗ Tidak ditemukan: Danau Kembar
# ✓ Ditemukan: Bukit Barisan
# ✓ Ditemukan: Pulau Tikus
# ✗ Tidak ditemukan: Pantai Mutun
# ...

# %%
from geopy.geocoders import Nominatim
import pandas as pd
import time

wisata_sumsel_list = [
    "Danau Ranau", "Pagar Alam", "Lematang Indah Golf Course", "Bukit Serelo",
    "Air Terjun Lematang Indah", "Candi Bumi Ayu", "Museum Balaputera Dewa", "Danau Teluk Gelam",
    "Puncak Gunung Dempo", "Air Terjun Lematang", "Taman Wisata Alam Punti Kayu", "Sungai Musi",
    "Benteng Kuto Besak", "Danau Rambutan", "Air Terjun Curup Selampung", "Taman Kota Pagar Alam",
    "Kampung Adat Suku Anak Dalam", "Pulau Kemaro", "Hutan Mangrove Sungsang", "Taman Wisata Alam Pematang Gubernur",
    "Bukit Barisan Selatan", "Pantai Pasir Putih Tanjung Jabo", "Air Terjun Gunung Dempo", "Danau Ranau Way Kanan",
    "Museum Sultan Mahmud Badaruddin II", "Air Terjun Batu Kuning", "Taman Nasional Bukit Barisan Selatan",
    "Pantai Pasir Putih", "Desa Wisata Bedeng", "Danau Ranau Teluk Betung", "Gunung Dempo",
    "Air Terjun Lematang Indah", "Taman Wisata Alam Bukit Serelo", "Pulau Kemaro", "Sungai Musi",
    "Benteng Kuto Besak", "Bukit Besar", "Air Terjun Lubuk Raja", "Kampung Rambutan",
    "Danau Rambutan", "Air Terjun Batu Kuning", "Taman Kota Palembang", "Bukit Barisan Selatan",
    "Pulau Kemaro", "Danau Ranau", "Benteng Kuto Besak", "Air Terjun Curup Selampung",
    "Taman Wisata Alam Punti Kayu", "Pantai Pasir Putih Tanjung Jabo", "Bukit Serelo"
]

geolocator = Nominatim(user_agent="wisata_sumsel_geocoder")
results = []

for nama in wisata_sumsel_list:
    try:
        query = f"{nama}, Sumatera Selatan, Indonesia"
        location = geolocator.geocode(query, exactly_one=True, addressdetails=True)
        if location:
            addr = location.raw.get('address', {})
            results.append({
                "nama_wisata": nama,
                "latitude": location.latitude,
                "longitude": location.longitude,
                "alamat": location.address,
                "provinsi": addr.get('state', ''),
                "kota_kabupaten": addr.get('city', '') or addr.get('county', '') or addr.get('region', '')
            })
            print(f"✓ Ditemukan: {nama}")
        else:
            results.append({
                "nama_wisata": nama,
                "latitude": None,
                "longitude": None,
                "alamat": "Not Found",
                "provinsi": "",
                "kota_kabupaten": ""
            })
            print(f"✗ Tidak ditemukan: {nama}")
    except Exception as e:
        results.append({
            "nama_wisata": nama,
            "latitude": None,
            "longitude": None,
            "alamat": f"Error: {e}",
            "provinsi": "",
            "kota_kabupaten": ""
        })
        print(f"⚠️ Error: {nama} - {e}")
    time.sleep(1)

df = pd.DataFrame(results)
df.to_csv("wisata_sumatera_selatan_geocoding.csv", index=False)
print("✅ Data wisata Sumatera Selatan berhasil disimpan ke 'wisata_sumatera_selatan_geocoding.csv'")
# Out:
# ✓ Ditemukan: Danau Ranau
# ✓ Ditemukan: Pagar Alam
# ✗ Tidak ditemukan: Lematang Indah Golf Course
# ✓ Ditemukan: Bukit Serelo
# ✗ Tidak ditemukan: Air Terjun Lematang Indah
# ✗ Tidak ditemukan: Candi Bumi Ayu
# ✓ Ditemukan: Museum Balaputera Dewa
# ✓ Ditemukan: Danau Teluk Gelam
# ✗ Tidak ditemukan: Puncak Gunung Dempo
# ✗ Tidak ditemukan: Air Terjun Lematang
# ✗ Tidak ditemukan: Taman Wisata Alam Punti Kayu
# ✓ Ditemukan: Sungai Musi
# ✓ Ditemukan: Benteng Kuto Besak
# ✓ Ditemukan: Danau Rambutan
# ✗ Tidak ditemukan: Air Terjun Curup Selampung
# ✗ Tidak ditemukan: Taman Kota Pagar Alam
# ✗ Tidak ditemukan: Kampung Adat Suku Anak Dalam
# ✓ Ditemukan: Pulau Kemaro
# ✗ Tidak ditemukan: Hutan Mangrove Sungsang
# ✗ Tidak ditemukan: Taman Wisata Alam Pematang Gubernur
# ✓ Ditemukan: Bukit Barisan Selatan
# ✗ Tidak ditemukan: Pantai Pasir Putih Tanjung Jabo
# ✗ Tidak ditemukan: Air Terjun Gunung Dempo
# ✗ Tidak ditemukan: Danau Ranau Way Kanan
# ...

# %%
from geopy.geocoders import Nominatim
import pandas as pd
import time

wisata_lampung_list = [
    "Pantai Mutun", "Pahawang Island", "Gunung Anak Krakatau", "Way Kambas National Park",
    "Pantai Sari Ringgung", "Pulau Pahawang", "Danau Ranau", "Bukit Sakura",
    "Air Terjun Lembah Pelangi", "Pantai Klara", "Taman Nasional Bukit Barisan Selatan",
    "Pulau Tegal", "Pantai Gigi Hiu", "Goa Lalay", "Danau Sebesi",
    "Pantai Labuhan Jukung", "Hutan Wisata Bandar Lampung", "Pantai Mutun Lampung",
    "Pulau Kelapa", "Pantai Pesisir Barat", "Taman Wisata Way Kanan",
    "Bukit Mandailing", "Pantai Teluk Kiluan", "Air Terjun Curup Gangsa",
    "Danau Suoh", "Pulau Pasaran", "Kampung Nelayan Kiluan", "Pantai Krui",
    "Bukit Barisan", "Gunung Rajabasa", "Air Terjun Putri Malu", "Pulau Pahawang Besar",
    "Taman Nasional Bukit Barisan Selatan", "Pantai Labuhan Maringgai",
    "Danau Gunung Tujuh", "Pantai Batu Lapis", "Sungai Way Seputih",
    "Air Terjun Way Lalaan", "Pantai Tanjung Setia", "Bukit Tunggul",
    "Pulau Legundi", "Pantai Pengibul", "Museum Lampung", "Bukit Pangonan",
    "Pulau Pasaran", "Air Terjun Teluk Pandan", "Danau Ranau", "Pantai Mutun",
    "Gunung Betung", "Taman Wisata Alam Bukit Barisan"
]

geolocator = Nominatim(user_agent="wisata_lampung_geocoder")
results = []

for nama in wisata_lampung_list:
    try:
        query = f"{nama}, Lampung, Indonesia"
        location = geolocator.geocode(query, exactly_one=True, addressdetails=True)
        if location:
            addr = location.raw.get('address', {})
            results.append({
                "nama_wisata": nama,
                "latitude": location.latitude,
                "longitude": location.longitude,
                "alamat": location.address,
                "provinsi": addr.get('state', ''),
                "kota_kabupaten": addr.get('city', '') or addr.get('county', '') or addr.get('region', '')
            })
            print(f"✓ Ditemukan: {nama}")
        else:
            results.append({
                "nama_wisata": nama,
                "latitude": None,
                "longitude": None,
                "alamat": "Not Found",
                "provinsi": "",
                "kota_kabupaten": ""
            })
            print(f"✗ Tidak ditemukan: {nama}")
    except Exception as e:
        results.append({
            "nama_wisata": nama,
            "latitude": None,
            "longitude": None,
            "alamat": f"Error: {e}",
            "provinsi": "",
            "kota_kabupaten": ""
        })
        print(f"⚠️ Error: {nama} - {e}")
    time.sleep(1)

df = pd.DataFrame(results)
df.to_csv("wisata_lampung_geocoding.csv", index=False)
print("✅ Data wisata Lampung berhasil disimpan ke 'wisata_lampung_geocoding.csv'")
# Out:
# ✓ Ditemukan: Pantai Mutun
# ✓ Ditemukan: Pahawang Island
# ✗ Tidak ditemukan: Gunung Anak Krakatau
# ✓ Ditemukan: Way Kambas National Park
# ✗ Tidak ditemukan: Pantai Sari Ringgung
# ✓ Ditemukan: Pulau Pahawang
# ✓ Ditemukan: Danau Ranau
# ✗ Tidak ditemukan: Bukit Sakura
# ✗ Tidak ditemukan: Air Terjun Lembah Pelangi
# ✗ Tidak ditemukan: Pantai Klara
# ✓ Ditemukan: Taman Nasional Bukit Barisan Selatan
# ✓ Ditemukan: Pulau Tegal
# ✗ Tidak ditemukan: Pantai Gigi Hiu
# ✗ Tidak ditemukan: Goa Lalay
# ✗ Tidak ditemukan: Danau Sebesi
# ✗ Tidak ditemukan: Pantai Labuhan Jukung
# ✗ Tidak ditemukan: Hutan Wisata Bandar Lampung
# ✓ Ditemukan: Pantai Mutun Lampung
# ✓ Ditemukan: Pulau Kelapa
# ✗ Tidak ditemukan: Pantai Pesisir Barat
# ✗ Tidak ditemukan: Taman Wisata Way Kanan
# ✗ Tidak ditemukan: Bukit Mandailing
# ✗ Tidak ditemukan: Pantai Teluk Kiluan
# ✗ Tidak ditemukan: Air Terjun Curup Gangsa
# ✗ Tidak ditemukan: Danau Suoh
# ✓ Ditemukan: Pulau Pasaran
# ...

# %%
from geopy.geocoders import Nominatim
import pandas as pd
import time

wisata_bangka_belitung_list = [
    "Pantai Parai Tenggiri", "Pantai Tanjung Tinggi", "Pantai Tanjung Kelayang", "Pulau Lengkuas",
    "Danau Kaolin", "Bukit Berahu", "Pantai Matras", "Air Terjun Batu Betumpang", "Pantai Pasir Padi",
    "Pulau Lepar", "Desa Wisata Air Anyir", "Pantai Batu Baginde", "Pulau Ketawai", "Pantai Tikus Emas",
    "Pantai Penyalai", "Pantai Penyusuk", "Pantai Gusung", "Pantai Nam Nam", "Danau Penda",
    "Goa Panggul", "Bukit Batu Bangka", "Pantai Tanjung Kerasak", "Pulau Kepayang", "Pantai Saka",
    "Pulau Rimau", "Bukit Muntai", "Pantai Batu Dinding", "Pantai Pasir Padi", "Pulau Besar",
    "Pantai Batu Bedaun", "Danau Rusa", "Pantai Batu Kerbau", "Pantai Tanjung Tinggi", "Pulau Babi",
    "Pantai Batu Kerbau", "Pantai Tanjung Berikat", "Pulau Semujur", "Pulau Pelangi", "Pantai Batu Berdaun",
    "Pulau Pamutusan", "Bukit Batu Kapur", "Pantai Air Saga", "Pantai Bukit Berahu", "Danau Koalin",
    "Pulau Ketawai", "Pantai Penyalai", "Pulau Lengkuas", "Pantai Tanjung Tinggi"
]

geolocator = Nominatim(user_agent="wisata_bangka_belitung_geocoder")
results = []

for nama in wisata_bangka_belitung_list:
    try:
        query = f"{nama}, Bangka Belitung, Indonesia"
        location = geolocator.geocode(query, exactly_one=True, addressdetails=True)
        if location:
            addr = location.raw.get('address', {})
            results.append({
                "nama_wisata": nama,
                "latitude": location.latitude,
                "longitude": location.longitude,
                "alamat": location.address,
                "provinsi": addr.get('state', ''),
                "kota_kabupaten": addr.get('city', '') or addr.get('county', '') or addr.get('region', '')
            })
            print(f"✓ Ditemukan: {nama}")
        else:
            results.append({
                "nama_wisata": nama,
                "latitude": None,
                "longitude": None,
                "alamat": "Not Found",
                "provinsi": "",
                "kota_kabupaten": ""
            })
            print(f"✗ Tidak ditemukan: {nama}")
    except Exception as e:
        results.append({
            "nama_wisata": nama,
            "latitude": None,
            "longitude": None,
            "alamat": f"Error: {e}",
            "provinsi": "",
            "kota_kabupaten": ""
        })
        print(f"⚠️ Error: {nama} - {e}")
    time.sleep(1)

df = pd.DataFrame(results)
df.to_csv("wisata_bangka_belitung_geocoding.csv", index=False)
print("✅ Data wisata Bangka Belitung berhasil disimpan ke 'wisata_bangka_belitung_geocoding.csv'")
# Out:
# ✗ Tidak ditemukan: Pantai Parai Tenggiri
# ✗ Tidak ditemukan: Pantai Tanjung Tinggi
# ✗ Tidak ditemukan: Pantai Tanjung Kelayang
# ✓ Ditemukan: Pulau Lengkuas
# ✓ Ditemukan: Danau Kaolin
# ✗ Tidak ditemukan: Bukit Berahu
# ✗ Tidak ditemukan: Pantai Matras
# ✗ Tidak ditemukan: Air Terjun Batu Betumpang
# ✓ Ditemukan: Pantai Pasir Padi
# ✓ Ditemukan: Pulau Lepar
# ✗ Tidak ditemukan: Desa Wisata Air Anyir
# ✗ Tidak ditemukan: Pantai Batu Baginde
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=Pulau+Ketawai%2C+Bangka+Belitung%2C+Indonesia&format=json&limit=1&addressdetails=1
# ✓ Ditemukan: Pulau Ketawai
# ✓ Ditemukan: Pantai Tikus Emas
# ✗ Tidak ditemukan: Pantai Penyalai
# ✗ Tidak ditemukan: Pantai Penyusuk
# ✗ Tidak ditemukan: Pantai Gusung
# ...

# %%
from geopy.geocoders import Nominatim
import pandas as pd
import time

wisata_jakarta_list = [
    "Monumen Nasional", "Kota Tua Jakarta", "Museum Nasional Indonesia", "Taman Mini Indonesia Indah",
    "Ancol Dreamland", "Dunia Fantasi", "Taman Impian Jaya Ancol", "Museum Bank Indonesia", "Museum Wayang",
    "Kebun Binatang Ragunan", "Museum Fatahillah", "Masjid Istiqlal", "Gereja Katedral Jakarta", "Taman Suropati",
    "Taman Menteng", "Museum Seni Rupa dan Keramik", "Setu Babakan", "Museum Satria Mandala", "Pasar Baru",
    "Taman Waduk Pluit", "Planetarium Jakarta", "Monumen Pancasila Sakti", "Museum Bahari", "Pulau Onrust",
    "Museum Sejarah Jakarta", "Taman Ismail Marzuki", "Taman Anggrek Mall", "Pacific Place Mall",
    "Plaza Indonesia", "Grand Indonesia Shopping Town", "Museum Layang-layang", "Galeri Nasional Indonesia",
    "Museum Taman Prasasti", "Monumen Patung Dirgantara", "Taman Menteng", "Pulau Seribu", "Taman Ekspresi",
    "Taman Ayodya", "Museum Bank Mandiri", "Taman Spatodhea", "Museum Keprajuritan", "Monumen Perjuangan Rakyat",
    "Museum Prasasti Jakarta", "Taman Suropati", "Museum Wayang Orang Bharata", "Taman Lalu Lintas",
    "Museum Bahari", "Museum Reksa Artha", "Museum Tekstil", "Museum Keramik", "Museum Sejarah Jakarta",
    "Museum Bahari", "Museum Fatahillah", "Taman Kalijodo", "Museum Purna Bhakti Pertiwi", "Taman Honda Tebet",
    "Pasar Santa", "Museum Si Pitung", "Pulau Ayer", "Museum Bank Indonesia", "Museum Nasional Indonesia",
    "Museum Wayang", "Museum Seni Rupa dan Keramik", "Setu Babakan", "Taman Menteng", "Taman Suropati",
    "Ancol Beach", "Taman Impian Jaya Ancol", "Dunia Fantasi", "Waterbom Jakarta", "SeaWorld Ancol",
    "Pantai Carnaval Ancol", "Pulau Onrust", "Taman Mini Indonesia Indah", "Kebun Binatang Ragunan",
    "Museum Keprajuritan", "Museum Bahari", "Museum Sejarah Jakarta", "Museum Purna Bhakti Pertiwi",
    "Taman Lalu Lintas", "Monumen Nasional", "Monumen Patung Dirgantara", "Taman Ayodya", "Taman Anggrek Mall",
    "Pacific Place Mall", "Plaza Indonesia", "Grand Indonesia", "Museum Bank Mandiri", "Museum Taman Prasasti",
    "Museum Reksa Artha", "Museum Tekstil", "Museum Keramik", "Museum Layang-Layang", "Galeri Nasional Indonesia",
    "Museum Wayang Orang Bharata", "Museum Si Pitung", "Taman Honda Tebet", "Pasar Santa", "Pulau Ayer",
    "Museum Prasasti"
]

geolocator = Nominatim(user_agent="wisata_jakarta_geocoder")
results = []

for nama in wisata_jakarta_list:
    try:
        query = f"{nama}, Jakarta, Indonesia"
        location = geolocator.geocode(query, exactly_one=True, addressdetails=True)
        if location:
            addr = location.raw.get('address', {})
            results.append({
                "nama_wisata": nama,
                "latitude": location.latitude,
                "longitude": location.longitude,
                "alamat": location.address,
                "provinsi": addr.get('state', ''),
                "kota_kabupaten": addr.get('city', '') or addr.get('county', '') or addr.get('region', '')
            })
            print(f"✓ Ditemukan: {nama}")
        else:
            results.append({
                "nama_wisata": nama,
                "latitude": None,
                "longitude": None,
                "alamat": "Not Found",
                "provinsi": "",
                "kota_kabupaten": ""
            })
            print(f"✗ Tidak ditemukan: {nama}")
    except Exception as e:
        results.append({
            "nama_wisata": nama,
            "latitude": None,
            "longitude": None,
            "alamat": f"Error: {e}",
            "provinsi": "",
            "kota_kabupaten": ""
        })
        print(f"⚠️ Error: {nama} - {e}")
    time.sleep(1)

df = pd.DataFrame(results)
df.to_csv("wisata_dki_jakarta_geocoding.csv", index=False)
print("✅ Data wisata DKI Jakarta berhasil disimpan ke 'wisata_dki_jakarta_geocoding.csv'")
# Out:
# ✓ Ditemukan: Monumen Nasional
# ✓ Ditemukan: Kota Tua Jakarta
# ✗ Tidak ditemukan: Museum Nasional Indonesia
# ✓ Ditemukan: Taman Mini Indonesia Indah
# ✓ Ditemukan: Ancol Dreamland
# ✓ Ditemukan: Dunia Fantasi
# ✓ Ditemukan: Taman Impian Jaya Ancol
# ✓ Ditemukan: Museum Bank Indonesia
# ✓ Ditemukan: Museum Wayang
# ✓ Ditemukan: Kebun Binatang Ragunan
# ✓ Ditemukan: Museum Fatahillah
# ✓ Ditemukan: Masjid Istiqlal
# ✓ Ditemukan: Gereja Katedral Jakarta
# ✓ Ditemukan: Taman Suropati
# ✓ Ditemukan: Taman Menteng
# ✓ Ditemukan: Museum Seni Rupa dan Keramik
# ✓ Ditemukan: Setu Babakan
# ✓ Ditemukan: Museum Satria Mandala
# ✓ Ditemukan: Pasar Baru
# ✓ Ditemukan: Taman Waduk Pluit
# ✓ Ditemukan: Planetarium Jakarta
# ✓ Ditemukan: Monumen Pancasila Sakti
# ✓ Ditemukan: Museum Bahari
# ✓ Ditemukan: Pulau Onrust
# ✓ Ditemukan: Museum Sejarah Jakarta
# ✓ Ditemukan: Taman Ismail Marzuki
# ✓ Ditemukan: Taman Anggrek Mall
# ✓ Ditemukan: Pacific Place Mall
# ✓ Ditemukan: Plaza Indonesia
# ...

# %%
from geopy.geocoders import Nominatim
import pandas as pd
import time

wisata_jabar_list = [
    "Kawah Putih", "Tangkuban Perahu", "Situ Patenggang", "Gunung Papandayan", "Curug Cimahi",
    "Trans Studio Bandung", "Dusun Bambu", "Farmhouse Lembang", "Tebing Keraton", "Taman Hutan Raya Ir. H. Juanda",
    "Situ Cileunca", "Gunung Gede Pangrango", "Maribaya Natural Hot Spring Resort", "Saung Angklung Udjo",
    "Taman Bunga Nusantara", "Situ Ciburuy", "Taman Nasional Gunung Gede Pangrango", "Pantai Pangandaran",
    "Goa Pawon", "Kampung Naga", "Curug Malela", "Curug Cimanggu", "Curug Batu Templek",
    "Curug Cikaso", "Kebun Raya Bogor", "Istana Bogor", "Curug Cimory", "Gunung Burangrang",
    "Curug Nangka", "Kampung Sampireun", "Situ Rawa Gede", "Curug Cibeureum", "Ciletuh Geopark",
    "The Lodge Maribaya", "Kebun Teh Puncak", "Situ Cipanten", "Curug Cikondang", "Curug Cipendok",
    "Kampung Gajah Wonderland", "Kawah Ratu", "Gunung Tampomas", "Cibodas Botanical Garden", "Situ Cisanti",
    "Kampung Ciburial", "Pantai Santolo", "Gunung Karacak", "Situ Bagendit", "Curug Cigorobog",
    "Curug Leuwi Lieuk", "Taman Wisata Alam Gunung Masigit Kareumbi", "Museum Geologi Bandung",
    "Situ Walini", "Museum Konferensi Asia Afrika", "Curug Tilu Leuwi Opat", "Curug Sawer",
    "Danau Lido", "Gunung Guntur", "Curug Cipeuteuy", "Pantai Batu Karas", "Curug Muara Jaya",
    "Kawah Kamojang", "Bukit Moko", "Situ Sanghyang Taraje", "Curug Cimory River Side",
    "Gunung Putri Lembang", "Pantai Citepus", "Taman Miniatur Kereta Api", "Curug Cigamea",
    "Curug Cibaliung", "Pantai Santolo", "Curug Cibereum"
]

geolocator = Nominatim(user_agent="wisata_jabar_geocoder")
results = []

for nama in wisata_jabar_list:
    try:
        query = f"{nama}, Jawa Barat, Indonesia"
        location = geolocator.geocode(query, exactly_one=True, addressdetails=True)
        if location:
            addr = location.raw.get('address', {})
            results.append({
                "nama_wisata": nama,
                "latitude": location.latitude,
                "longitude": location.longitude,
                "alamat": location.address,
                "provinsi": addr.get('state', ''),
                "kota_kabupaten": addr.get('city', '') or addr.get('county', '') or addr.get('region', '')
            })
            print(f"✓ Ditemukan: {nama}")
        else:
            results.append({
                "nama_wisata": nama,
                "latitude": None,
                "longitude": None,
                "alamat": "Not Found",
                "provinsi": "",
                "kota_kabupaten": ""
            })
            print(f"✗ Tidak ditemukan: {nama}")
    except Exception as e:
        results.append({
            "nama_wisata": nama,
            "latitude": None,
            "longitude": None,
            "alamat": f"Error: {e}",
            "provinsi": "",
            "kota_kabupaten": ""
        })
        print(f"⚠️ Error: {nama} - {e}")
    time.sleep(1)

df = pd.DataFrame(results)
df.to_csv("wisata_jawa_barat_geocoding.csv", index=False)
print("✅ Data wisata Jawa Barat berhasil disimpan ke 'wisata_jawa_barat_geocoding.csv'")
# Out:
# ✓ Ditemukan: Kawah Putih
# ✓ Ditemukan: Tangkuban Perahu
# ✓ Ditemukan: Situ Patenggang
# ✓ Ditemukan: Gunung Papandayan
# ✓ Ditemukan: Curug Cimahi
# ✓ Ditemukan: Trans Studio Bandung
# ✓ Ditemukan: Dusun Bambu
# ✓ Ditemukan: Farmhouse Lembang
# ✓ Ditemukan: Tebing Keraton
# ✓ Ditemukan: Taman Hutan Raya Ir. H. Juanda
# ✓ Ditemukan: Situ Cileunca
# ✓ Ditemukan: Gunung Gede Pangrango
# ✗ Tidak ditemukan: Maribaya Natural Hot Spring Resort
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=Saung+Angklung+Udjo%2C+Jawa+Barat%2C+Indonesia&format=json&limit=1&addressdetails=1
# ✓ Ditemukan: Saung Angklung Udjo
# ✓ Ditemukan: Taman Bunga Nusantara
# ✓ Ditemukan: Situ Ciburuy
# ✓ Ditemukan: Taman Nasional Gunung Gede Pangrango
# ✓ Ditemukan: Pantai Pangandaran
# ...

# %%
from geopy.geocoders import Nominatim
import pandas as pd
import time

# List 100 tempat wisata populer Jawa Tengah tanpa duplikasi
wisata_jateng_list = [
    "Candi Borobudur", "Candi Prambanan", "Keraton Surakarta", "Keraton Yogyakarta", "Taman Sari",
    "Gunung Merbabu", "Gunung Merapi", "Pantai Parangtritis", "Goa Pindul", "Kebun Raya Baturraden",
    "Curug Cimahi", "Pantai Kartini", "Pantai Teluk Penyu", "Pantai Bandengan", "Museum Sonobudoyo",
    "Museum Kereta Keraton", "Museum Ranggawarsita", "Museum Wayang Purwa", "Museum Radya Pustaka",
    "Museum Tosan Aji", "Museum Sangiran", "Museum Batik Pekalongan", "Alun-Alun Kota Semarang",
    "Alun-Alun Kota Solo", "Alun-Alun Kota Magelang", "Taman Rekreasi Sangkrah", "Taman Wisata Air Tlaga Sunyi",
    "Puncak Sikunir Dieng", "Dieng Plateau", "Kawah Sikidang", "Telaga Warna", "Telaga Pengilon",
    "Bukit Sikunir", "Pantai Ngrenehan", "Pantai Glagah", "Pantai Bandengan", "Pantai Karang Jahe",
    "Pantai Congot", "Pantai Jatimalang", "Pantai Bopong", "Pantai Krakal", "Pantai Sepanjang",
    "Curug Lawe", "Curug Benowo", "Curug Pulosari", "Curug Ceheng", "Curug Cimandaway",
    "Curug Setawing", "Curug Sewu", "Curug Kali Pancur", "Candi Mendut", "Candi Pawon",
    "Candi Kalasan", "Candi Sambisari", "Candi Plaosan", "Candi Ratu Boko", "Candi Ijo",
    "Candi Sari", "Kawah Merapi", "Goa Jatijajar", "Goa Kalisuci", "Goa Pindul",
    "Goa Semar", "Goa Lanang", "Goa Selarong", "Goa Kreo", "Taman Nasional Gunung Merbabu",
    "Taman Nasional Gunung Merapi", "Gunung Lawu", "Gunung Slamet", "Gunung Sindoro", "Gunung Sumbing",
    "Kebun Raya Purwodadi", "Kebun Raya Baturraden", "Taman Satwa Taru Jurug", "Taman Margasatwa Semarang",
    "Taman Mini Jawa Tengah", "Kampung Batik Kauman", "Kampung Wisata Kandri", "Kampung Batik Laweyan",
    "Kampung Batik Giriloyo", "Kampoeng Batik Laweyan", "Pasar Klewer", "Pasar Johar",
    "Pasar Beringharjo", "Pasar Triwindu", "Puri Mangkunegaran", "Pura Mangkunegaran",
    "Benteng Vastenburg", "Benteng Pendem", "Museum Keris", "Museum Keraton Surakarta",
    "Museum Keraton Yogyakarta", "Museum Wayang", "Museum Purbakala Sangiran", "Museum Ronggowarsito",
    "Museum Sejarah Kota Semarang", "Museum Jamu Nyonya Meneer", "Museum Bank Indonesia Semarang"
]

# Inisialisasi geolocator
geolocator = Nominatim(user_agent="wisata_jateng_geocoder")

results = []

for nama in wisata_jateng_list:
    try:
        query = f"{nama}, Jawa Tengah, Indonesia"
        location = geolocator.geocode(query, exactly_one=True, addressdetails=True)
        if location:
            addr = location.raw.get('address', {})
            results.append({
                "nama_wisata": nama,
                "latitude": location.latitude,
                "longitude": location.longitude,
                "alamat": location.address,
                "provinsi": addr.get('state', ''),
                "kota_kabupaten": addr.get('city', '') or addr.get('county', '') or addr.get('region', '')
            })
            print(f"✓ Ditemukan: {nama}")
        else:
            results.append({
                "nama_wisata": nama,
                "latitude": None,
                "longitude": None,
                "alamat": "Not Found",
                "provinsi": "",
                "kota_kabupaten": ""
            })
            print(f"✗ Tidak ditemukan: {nama}")
    except Exception as e:
        results.append({
            "nama_wisata": nama,
            "latitude": None,
            "longitude": None,
            "alamat": f"Error: {e}",
            "provinsi": "",
            "kota_kabupaten": ""
        })
        print(f"⚠️ Error: {nama} - {e}")
    time.sleep(1)  # Hindari limitasi

# Simpan hasil ke CSV
df = pd.DataFrame(results)
df.to_csv("wisata_jawa_tengah_geocoding.csv", index=False)
print("✅ Data wisata Jawa Tengah berhasil disimpan ke 'wisata_jawa_tengah_geocoding.csv'")
# Out:
# ✓ Ditemukan: Candi Borobudur
# ✓ Ditemukan: Candi Prambanan
# ✓ Ditemukan: Keraton Surakarta
# ✗ Tidak ditemukan: Keraton Yogyakarta
# ✓ Ditemukan: Taman Sari
# ✓ Ditemukan: Gunung Merbabu
# ✓ Ditemukan: Gunung Merapi
# ✗ Tidak ditemukan: Pantai Parangtritis
# ✗ Tidak ditemukan: Goa Pindul
# ✓ Ditemukan: Kebun Raya Baturraden
# ✗ Tidak ditemukan: Curug Cimahi
# ✓ Ditemukan: Pantai Kartini
# ✓ Ditemukan: Pantai Teluk Penyu
# ✓ Ditemukan: Pantai Bandengan
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=Museum+Sonobudoyo%2C+Jawa+Tengah%2C+Indonesia&format=json&limit=1&addressdetails=1
# ✗ Tidak ditemukan: Museum Sonobudoyo
# ✗ Tidak ditemukan: Museum Kereta Keraton
# ✓ Ditemukan: Museum Ranggawarsita
# ✗ Tidak ditemukan: Museum Wayang Purwa
# ...

# %%
from geopy.geocoders import Nominatim
import pandas as pd
import time

wisata_diy_list = [
    "Candi Prambanan", "Candi Ratu Boko", "Keraton Yogyakarta", "Taman Sari",
    "Gunung Merapi", "Pantai Parangtritis", "Pantai Depok", "Pantai Indrayanti",
    "Pantai Timang", "Goa Pindul", "Goa Jomblang", "Goa Cerme",
    "Museum Sonobudoyo", "Museum Ullen Sentalu", "Museum Affandi",
    "Tebing Breksi", "Alun-Alun Kidul Yogyakarta", "Alun-Alun Utara",
    "Bukit Bintang", "Kebun Buah Mangunan", "Kebun Raya Gamping",
    "Pantai Siung", "Pantai Pok Tunggal", "Pantai Sundak", "Pantai Baron",
    "Pantai Krakal", "Pantai Kukup", "Pantai Sadranan",
    "Museum Dirgantara Mandala", "Museum Benteng Vredeburg",
    "Museum Batik Yogyakarta", "Museum Wayang Kekayon",
    "Taman Pintar Yogyakarta", "Pantai Glagah", "Pantai Samas",
    "Hutan Pinus Mangunan", "Hutan Pinus Pengger",
    "Gunung Merbabu", "Gunung Lawu", "Kaliurang",
    "Puncak Suroloyo", "Puncak Becici", "Pantai Parangtritis",
    "Grojogan Sewu", "Curug Kedung Pedut", "Curug Lepo",
    "Taman Pelangi Monjali", "Taman Wisata Kaliurang",
    "Pasar Beringharjo", "Pasar Kranggan"
]

geolocator = Nominatim(user_agent="wisata_diy_geocoder")
results = []

for nama in wisata_diy_list:
    try:
        query = f"{nama}, Yogyakarta, Indonesia"
        location = geolocator.geocode(query, exactly_one=True, addressdetails=True)
        if location:
            addr = location.raw.get('address', {})
            results.append({
                "nama_wisata": nama,
                "latitude": location.latitude,
                "longitude": location.longitude,
                "alamat": location.address,
                "provinsi": addr.get('state', ''),
                "kota_kabupaten": addr.get('city', '') or addr.get('county', '') or addr.get('region', '')
            })
            print(f"✓ Ditemukan: {nama}")
        else:
            results.append({
                "nama_wisata": nama,
                "latitude": None,
                "longitude": None,
                "alamat": "Not Found",
                "provinsi": "",
                "kota_kabupaten": ""
            })
            print(f"✗ Tidak ditemukan: {nama}")
    except Exception as e:
        results.append({
            "nama_wisata": nama,
            "latitude": None,
            "longitude": None,
            "alamat": f"Error: {e}",
            "provinsi": "",
            "kota_kabupaten": ""
        })
        print(f"⚠️ Error: {nama} - {e}")
    time.sleep(1)

df = pd.DataFrame(results)
df.to_csv("wisata_yogyakarta_geocoding.csv", index=False)
print("✅ Data wisata DIY berhasil disimpan ke 'wisata_yogyakarta_geocoding.csv'")
# Out:
# ✓ Ditemukan: Candi Prambanan
# ✓ Ditemukan: Candi Ratu Boko
# ✓ Ditemukan: Keraton Yogyakarta
# ✓ Ditemukan: Taman Sari
# ✓ Ditemukan: Gunung Merapi
# ✓ Ditemukan: Pantai Parangtritis
# ✓ Ditemukan: Pantai Depok
# ✓ Ditemukan: Pantai Indrayanti
# ✓ Ditemukan: Pantai Timang
# ✓ Ditemukan: Goa Pindul
# ✓ Ditemukan: Goa Jomblang
# ✗ Tidak ditemukan: Goa Cerme
# ✓ Ditemukan: Museum Sonobudoyo
# ✓ Ditemukan: Museum Ullen Sentalu
# ✓ Ditemukan: Museum Affandi
# ✓ Ditemukan: Tebing Breksi
# ✓ Ditemukan: Alun-Alun Kidul Yogyakarta
# ✓ Ditemukan: Alun-Alun Utara
# ✓ Ditemukan: Bukit Bintang
# ✓ Ditemukan: Kebun Buah Mangunan
# ✗ Tidak ditemukan: Kebun Raya Gamping
# ✓ Ditemukan: Pantai Siung
# ✓ Ditemukan: Pantai Pok Tunggal
# ✓ Ditemukan: Pantai Sundak
# ✓ Ditemukan: Pantai Baron
# ✓ Ditemukan: Pantai Krakal
# ✓ Ditemukan: Pantai Kukup
# ✓ Ditemukan: Pantai Sadranan
# ✓ Ditemukan: Museum Dirgantara Mandala
# ✓ Ditemukan: Museum Benteng Vredeburg
# ✓ Ditemukan: Museum Batik Yogyakarta
# ...

# %%
from geopy.geocoders import Nominatim
import pandas as pd
import time

wisata_jatim_list = [
    "Gunung Bromo", "Gunung Semeru", "Pantai Pasir Putih Situbondo", "Pantai Balekambang", "Pantai Pelang",
    "Pantai Teluk Asmoro", "Pantai Rongkang", "Pantai Popoh", "Pantai Batu Bengkung", "Pantai Modangan",
    "Pantai Gili Labak", "Pantai Gili Iyang", "Pantai Kedung Celeng", "Pantai Watu Ulo", "Pantai Klayar",
    "Pantai Tanjung Kodok", "Pantai Papuma", "Pantai Bandealit", "Air Terjun Madakaripura", "Air Terjun Coban Rondo",
    "Air Terjun Tumpak Sewu", "Air Terjun Coban Pelangi", "Air Terjun Coban Glotak", "Air Terjun Sumber Pitu",
    "Air Terjun Sumber Pitu Malang", "Air Terjun Coban Jahe", "Air Terjun Coban Sewu", "Air Terjun Sumber Sirah",
    "Candi Penataran", "Candi Jabung", "Candi Jago", "Candi Wringin Lawang", "Candi Singosari",
    "Museum Angkut", "Museum Mpu Tantular", "Museum Raden Wijaya", "Museum Majapahit", "Museum Sempoerna",
    "Kebun Raya Purwodadi", "Kebun Raya Malang", "Taman Nasional Baluran", "Taman Nasional Meru Betiri",
    "Taman Nasional Bromo Tengger Semeru", "Taman Nasional Alas Purwo", "Taman Safari Prigen", "Kebun Teh Wonosari",
    "Kebun Teh Jamuska", "Kebun Teh Wonosari", "Kampung Warna-warni Jodipan", "Kampung Tridi Malang",
    "Jatim Park 1", "Jatim Park 2", "Batu Night Spectacular", "Selecta", "Eco Green Park",
    "Taman Rekreasi Wendit", "Alun-Alun Kota Malang", "Alun-Alun Kota Batu", "Alun-Alun Kota Surabaya",
    "Monumen Kapal Selam", "Monumen Tugu Pahlawan", "House of Sampoerna", "Surabaya Submarine Monument",
    "Masjid Cheng Hoo Surabaya", "Masjid Agung Surabaya", "Kampung Arab Ampel", "Suramadu Bridge",
    "Goa Cina", "Goa Maharani", "Goa Gong", "Goa Pandawa", "Goa Song", "Goa Moyo",
    "Bukit Jaddih", "Bukit Bulu", "Bukit Cinta", "Bukit Kapur Arosbaya", "Bukit Jamur",
    "Pantai Sipelot", "Pantai Nambung", "Pantai Banyu Anjlok", "Pantai Sembilan", "Pantai Papuma Jember",
    "Pantai Plengkung", "Pantai Pulau Merah", "Pantai Rajegwesi", "Pantai Watu Ulo"
]

geolocator = Nominatim(user_agent="wisata_jatim_geocoder")
results = []

for nama in wisata_jatim_list:
    try:
        query = f"{nama}, Jawa Timur, Indonesia"
        location = geolocator.geocode(query, exactly_one=True, addressdetails=True)
        if location:
            addr = location.raw.get('address', {})
            results.append({
                "nama_wisata": nama,
                "latitude": location.latitude,
                "longitude": location.longitude,
                "alamat": location.address,
                "provinsi": addr.get('state', ''),
                "kota_kabupaten": addr.get('city', '') or addr.get('county', '') or addr.get('region', '')
            })
            print(f"✓ Ditemukan: {nama}")
        else:
            results.append({
                "nama_wisata": nama,
                "latitude": None,
                "longitude": None,
                "alamat": "Not Found",
                "provinsi": "",
                "kota_kabupaten": ""
            })
            print(f"✗ Tidak ditemukan: {nama}")
    except Exception as e:
        results.append({
            "nama_wisata": nama,
            "latitude": None,
            "longitude": None,
            "alamat": f"Error: {e}",
            "provinsi": "",
            "kota_kabupaten": ""
        })
        print(f"⚠️ Error: {nama} - {e}")
    time.sleep(1)  # Delay agar tidak kena rate limit

df = pd.DataFrame(results)
df.to_csv("wisata_jawa_timur_geocoding.csv", index=False)
print("✅ Data wisata Jawa Timur berhasil disimpan ke 'wisata_jawa_timur_geocoding.csv'")
# Out:
# ✓ Ditemukan: Gunung Bromo
# ✓ Ditemukan: Gunung Semeru
# ✗ Tidak ditemukan: Pantai Pasir Putih Situbondo
# ✓ Ditemukan: Pantai Balekambang
# ✓ Ditemukan: Pantai Pelang
# ✗ Tidak ditemukan: Pantai Teluk Asmoro
# ✗ Tidak ditemukan: Pantai Rongkang
# ✓ Ditemukan: Pantai Popoh
# ✗ Tidak ditemukan: Pantai Batu Bengkung
# ✗ Tidak ditemukan: Pantai Modangan
# ✗ Tidak ditemukan: Pantai Gili Labak
# ✗ Tidak ditemukan: Pantai Gili Iyang
# ✗ Tidak ditemukan: Pantai Kedung Celeng
# ✗ Tidak ditemukan: Pantai Watu Ulo
# ✓ Ditemukan: Pantai Klayar
# ✗ Tidak ditemukan: Pantai Tanjung Kodok
# ✗ Tidak ditemukan: Pantai Papuma
# ✓ Ditemukan: Pantai Bandealit
# ✗ Tidak ditemukan: Air Terjun Madakaripura
# ✓ Ditemukan: Air Terjun Coban Rondo
# ✓ Ditemukan: Air Terjun Tumpak Sewu
# ✗ Tidak ditemukan: Air Terjun Coban Pelangi
# ✗ Tidak ditemukan: Air Terjun Coban Glotak
# ✗ Tidak ditemukan: Air Terjun Sumber Pitu
# ✗ Tidak ditemukan: Air Terjun Sumber Pitu Malang
# ✗ Tidak ditemukan: Air Terjun Coban Jahe
# ...

# %%
from geopy.geocoders import Nominatim
import pandas as pd
import time

wisata_banten_list = [
    "Pantai Anyer", "Pantai Carita", "Pantai Tanjung Lesung", "Pantai Sawarna", "Pantai Bagedur",
    "Pantai Ciputih", "Pantai Tanjung Kait", "Pantai Panimbang", "Pantai Tanjung Ratu", "Pantai Tanjung Lesung",
    "Pulau Umang", "Pulau Sangiang", "Pulau Panjang", "Pulau Tunda", "Pulau Rakata",
    "Gunung Karang", "Gunung Halimun Salak National Park", "Gunung Pulosari", "Gunung Sangiang",
    "Cagar Alam Pulau Sangiang", "Taman Nasional Ujung Kulon", "Taman Wisata Alam Gunung Halimun",
    "Curug Cimahi", "Curug Sawer", "Curug Cihanjaro", "Curug Cigangsa", "Curug Cikuluwung",
    "Curug Cibaliung", "Curug Leuwi Hejo", "Curug Leuwi Lieuk", "Curug Panjang", "Curug Citambur",
    "Curug Cimanggu", "Curug Sawer", "Candi Bojong", "Candi Leles", "Candi Cibedug",
    "Museum Benteng Heritage", "Museum Multatuli", "Museum Negeri Banten", "Museum Purbakala Cipari",
    "Museum Krakatau", "Museum Tsunami Banten", "Alun-Alun Kota Serang", "Alun-Alun Kota Cilegon",
    "Alun-Alun Kota Tangerang", "Kampung Baduy", "Kampung Naga", "Kampung Cikadu",
    "Kampung Adat Cisitu", "Kampung Adat Sindang Barang", "Kampung Wisata Alam Cimaja",
    "Kebun Raya Banten", "Kebun Raya Serang", "Kebun Raya Cilegon", "Kebun Raya Tangerang",
    "Benteng Speelwijk", "Benteng Surosowan", "Benteng Kaibon", "Benteng Pendem Cilegon",
    "Benteng Bubakan", "Benteng Karang Bolong", "Benteng Cituis", "Benteng Cimaja",
    "Pantai Anyer Waterboom", "Taman Nasional Ujung Kulon", "Pulau Panjang", "Pantai Binuangeun",
    "Pantai Sambolo", "Pantai Tanjung Lesung", "Pantai Karang Bokor", "Pantai Sawarna",
    "Pantai Pasir Putih", "Pantai Tanjung Layar", "Pantai Bagedur", "Pantai Ciputih",
    "Pantai Pulau Merak", "Pantai Panimbang", "Pantai Teluk Lada", "Pantai Tanjung Kelayang",
    "Pulau Umang", "Pulau Sangiang", "Pulau Tunda", "Pulau Sebuku", "Pulau Panaitan",
    "Curug Cikuluwung", "Curug Panjang", "Curug Cibaliung", "Curug Sawer", "Curug Cigangsa",
    "Curug Cimahi", "Curug Cimandaway", "Curug Citambur"
]

geolocator = Nominatim(user_agent="wisata_banten_geocoder")
results = []

for nama in wisata_banten_list:
    try:
        query = f"{nama}, Banten, Indonesia"
        location = geolocator.geocode(query, exactly_one=True, addressdetails=True)
        if location:
            addr = location.raw.get('address', {})
            results.append({
                "nama_wisata": nama,
                "latitude": location.latitude,
                "longitude": location.longitude,
                "alamat": location.address,
                "provinsi": addr.get('state', ''),
                "kota_kabupaten": addr.get('city', '') or addr.get('county', '') or addr.get('region', '')
            })
            print(f"✓ Ditemukan: {nama}")
        else:
            results.append({
                "nama_wisata": nama,
                "latitude": None,
                "longitude": None,
                "alamat": "Not Found",
                "provinsi": "",
                "kota_kabupaten": ""
            })
            print(f"✗ Tidak ditemukan: {nama}")
    except Exception as e:
        results.append({
            "nama_wisata": nama,
            "latitude": None,
            "longitude": None,
            "alamat": f"Error: {e}",
            "provinsi": "",
            "kota_kabupaten": ""
        })
        print(f"⚠️ Error: {nama} - {e}")
    time.sleep(1)  # Delay agar tidak kena rate limit

df = pd.DataFrame(results)
df.to_csv("wisata_banten_geocoding.csv", index=False)
print("✅ Data wisata Banten berhasil disimpan ke 'wisata_banten_geocoding.csv'")
# Out:
# ✗ Tidak ditemukan: Pantai Anyer
# ✓ Ditemukan: Pantai Carita
# ✗ Tidak ditemukan: Pantai Tanjung Lesung
# ✗ Tidak ditemukan: Pantai Sawarna
# ✗ Tidak ditemukan: Pantai Bagedur
# ✓ Ditemukan: Pantai Ciputih
# ✗ Tidak ditemukan: Pantai Tanjung Kait
# ✗ Tidak ditemukan: Pantai Panimbang
# ✗ Tidak ditemukan: Pantai Tanjung Ratu
# ✗ Tidak ditemukan: Pantai Tanjung Lesung
# ✓ Ditemukan: Pulau Umang
# ✗ Tidak ditemukan: Pulau Sangiang
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=Pulau+Panjang%2C+Banten%2C+Indonesia&format=json&limit=1&addressdetails=1
# ✗ Tidak ditemukan: Pulau Panjang
# ✗ Tidak ditemukan: Pulau Tunda
# ✗ Tidak ditemukan: Pulau Rakata
# ✓ Ditemukan: Gunung Karang
# ✓ Ditemukan: Gunung Halimun Salak National Park
# ✗ Tidak ditemukan: Gunung Pulosari
# ...

# %%
from geopy.geocoders import Nominatim
import pandas as pd
import time

wisata_bali_list = [
    "Pantai Kuta", "Pantai Sanur", "Pantai Nusa Dua", "Pantai Jimbaran", "Pantai Seminyak",
    "Pantai Padang Padang", "Pantai Dreamland", "Pantai Balangan", "Pantai Lovina", "Pantai Amed",
    "Pantai Candidasa", "Pantai Blue Lagoon", "Pantai Suluban", "Pantai Bias Tugel", "Pantai Melasti",
    "Pantai Pasir Putih", "Pantai Karma Kandara", "Pantai Green Bowl", "Pantai Yeh Gangga", "Pantai Seseh",
    "Gunung Agung", "Gunung Batur", "Danau Batur", "Danau Beratan", "Danau Tamblingan",
    "Pura Besakih", "Pura Ulun Danu Beratan", "Pura Tanah Lot", "Pura Uluwatu", "Pura Taman Ayun",
    "Taman Nasional Bali Barat", "Taman Ayun", "Taman Sukasada", "Taman Jepun", "Taman Nusa",
    "Monkey Forest Ubud", "Sacred Monkey Forest Sanctuary", "Goa Gajah", "Goa Lawah", "Goa Rang Reng",
    "Tegallalang Rice Terrace", "Jatiluwih Rice Terrace", "Campuhan Ridge Walk", "Bukit Campuhan",
    "Waterbom Bali", "Bali Safari and Marine Park", "Bali Bird Park", "Bali Zoo", "Bali Marine and Safari Park",
    "Museum Bali", "Museum Neka", "Museum Blanco Renaissance", "Museum Puri Lukisan", "Museum Rudana",
    "Museum Le Mayeur", "Museum Agung Rai", "Museum Setia Darma", "Museum Bali Heritage", "Museum Pasifika",
    "Ubud Palace", "Puri Saren Agung", "Kertha Gosa", "Istana Tampaksiring", "Istana Klungkung",
    "Pasar Seni Ubud", "Pasar Seni Sukawati", "Pasar Seni Kuta", "Pasar Seni Seminyak", "Pasar Badung",
    "Pasar Gianyar", "Pasar Celuk", "Pasar Mas", "Pasar Sindhu", "Pasar Kumbasari",
    "Bukit Campuhan", "Bukit Jimbaran", "Bukit Asah Bugbug", "Bukit Suluban", "Bukit Canggu",
    "Bukit Menjangan", "Air Terjun Gitgit", "Air Terjun Sekumpul", "Air Terjun Tegenungan", "Air Terjun Aling-Aling",
    "Air Terjun Tukad Cepung", "Air Terjun Banyumala", "Air Terjun Kanto Lampo", "Air Terjun Nungnung", "Air Terjun Sambangan",
    "Beachwalk Shopping Center", "Mall Bali Galeria", "Kuta Square", "Discovery Shopping Mall",
    "Lippo Mall Kuta", "Dewa Ruci Mall", "Krisna Oleh-oleh Bali", "Centro Bali Mall", "Bali Collection Mall",
    "Seminyak Village", "Sanglah Mall", "Plaza Renon", "Bali Mall", "T Galleria Bali", "Supernova Shopping Mall",
    "Bali Zoo Shopping Center", "Ubud Art Market", "Denpasar Mall", "Sukawati Art Market", "Joger Bali",
    "Canggu Plaza", "Denpasar Town Square", "Sungai Petani Mall", "Bali Nusa Dua Center"
]


geolocator = Nominatim(user_agent="wisata_bali_geocoder")
results = []

for nama in wisata_bali_list:
    try:
        query = f"{nama}, Bali, Indonesia"
        location = geolocator.geocode(query, exactly_one=True, addressdetails=True)
        if location:
            addr = location.raw.get('address', {})
            results.append({
                "nama_wisata": nama,
                "latitude": location.latitude,
                "longitude": location.longitude,
                "alamat": location.address,
                "provinsi": addr.get('state', ''),
                "kota_kabupaten": addr.get('city', '') or addr.get('county', '') or addr.get('region', '')
            })
            print(f"✓ Ditemukan: {nama}")
        else:
            results.append({
                "nama_wisata": nama,
                "latitude": None,
                "longitude": None,
                "alamat": "Not Found",
                "provinsi": "",
                "kota_kabupaten": ""
            })
            print(f"✗ Tidak ditemukan: {nama}")
    except Exception as e:
        results.append({
            "nama_wisata": nama,
            "latitude": None,
            "longitude": None,
            "alamat": f"Error: {e}",
            "provinsi": "",
            "kota_kabupaten": ""
        })
        print(f"⚠️ Error: {nama} - {e}")
    time.sleep(1)  # Delay agar tidak kena rate limit

df = pd.DataFrame(results)
df.to_csv("wisata_bali_geocoding.csv", index=False)
print("✅ Data wisata Bali berhasil disimpan ke 'wisata_bali_geocoding.csv'")
# Out:
# ✓ Ditemukan: Pantai Kuta
# ✓ Ditemukan: Pantai Sanur
# ✓ Ditemukan: Pantai Nusa Dua
# ✓ Ditemukan: Pantai Jimbaran
# ✓ Ditemukan: Pantai Seminyak
# ✓ Ditemukan: Pantai Padang Padang
# ✓ Ditemukan: Pantai Dreamland
# ✓ Ditemukan: Pantai Balangan
# ✓ Ditemukan: Pantai Lovina
# ✓ Ditemukan: Pantai Amed
# ✓ Ditemukan: Pantai Candidasa
# ✗ Tidak ditemukan: Pantai Blue Lagoon
# ✗ Tidak ditemukan: Pantai Suluban
# ✗ Tidak ditemukan: Pantai Bias Tugel
# ✗ Tidak ditemukan: Pantai Melasti
# ✗ Tidak ditemukan: Pantai Pasir Putih
# ✗ Tidak ditemukan: Pantai Karma Kandara
# ✗ Tidak ditemukan: Pantai Green Bowl
# ✗ Tidak ditemukan: Pantai Yeh Gangga
# ✓ Ditemukan: Pantai Seseh
# ✓ Ditemukan: Gunung Agung
# ✓ Ditemukan: Gunung Batur
# ✓ Ditemukan: Danau Batur
# ✓ Ditemukan: Danau Beratan
# ✓ Ditemukan: Danau Tamblingan
# ✓ Ditemukan: Pura Besakih
# ✓ Ditemukan: Pura Ulun Danu Beratan
# ✓ Ditemukan: Pura Tanah Lot
# ...

# %%
from geopy.geocoders import Nominatim
import pandas as pd
import time

wisata_ntb_list = [
    "Gunung Rinjani", "Danau Segara Anak", "Pantai Senggigi", "Pantai Kuta Lombok",
    "Pantai Selong Belanak", "Pantai Mawun", "Pantai Tanjung Aan", "Gili Trawangan",
    "Gili Air", "Gili Meno", "Gili Nanggu", "Gili Sulat", "Gili Kedis", "Gili Petelu",
    "Bukit Merese", "Bukit Pergasingan", "Bukit Selong", "Air Terjun Tiu Kelep",
    "Air Terjun Sendang Gile", "Pantai Pink", "Pantai Sire", "Pantai Malimbu",
    "Pantai Bangko-Bangko", "Pantai Nipah", "Pantai Batu Payung", "Pantai Mawun",
    "Pantai Gili Asahan", "Pantai Sekotong", "Pantai Awang", "Pantai Cemara",
    "Pantai Kerandangan", "Pantai Sembalun", "Pura Lingsar", "Pura Batu Bolong",
    "Pura Meru", "Museum Negeri Nusa Tenggara Barat", "Museum Negeri Mataram",
    "Taman Mayura", "Taman Narmada", "Taman Udayana", "Pasar Seni Mataram",
    "Pasar Seni Cakranegara", "Pasar Seni Ampenan", "Masjid Islamic Center NTB",
    "Masjid Hubbul Wathan", "Benteng Bayan", "Benteng Selaparang", "Benteng Karang",
    "Air Terjun Benang Stokel", "Air Terjun Benang Kelambu", "Air Terjun Gangga",
    "Air Terjun Tiu Pupus", "Air Terjun Batu Tibo", "Air Terjun Jukut", "Air Terjun Mangku Sakti",
    "Air Terjun Pengantin", "Danau Melintang", "Danau Segara Anak", "Danau Kebon Kodo",
    "Taman Wisata Alam Gunung Rinjani", "Taman Wisata Alam Gunung Tambora",
    "Kawasan Konservasi Perairan Gili Matra", "Taman Nasional Gunung Rinjani",
    "Taman Nasional Gunung Tambora", "Pulau Satonda", "Pulau Gili Banta",
    "Pulau Gili Lawang", "Pulau Gili Nanggu", "Pulau Gili Petelu", "Pulau Gili Sulat",
    "Pulau Moyo", "Pulau Kenawa", "Pulau Sumbawa Besar", "Pulau Lombok Timur",
    "Pantai Kencana", "Pantai Nipah", "Pantai Mandalika", "Pantai Seger",
    "Pantai Batu Layar", "Pantai Gerupuk", "Pantai Selong Belanak", "Pantai Mawun",
    "Bukit Merese", "Bukit Selong", "Bukit Pergasingan", "Bukit Tanak Awu",
    "Bukit Batu Payung", "Bukit Batu Layar", "Bukit Batu Tering", "Bukit Batu Belang",
    "Pasar Tradisional Ampenan", "Pasar Tradisional Kebon Roek", "Pasar Tradisional Cakranegara",
    "Museum NTB", "Museum Nusa Tenggara Barat", "Museum Peradaban Mandalika"
]

geolocator = Nominatim(user_agent="wisata_ntb_geocoder")
results = []

for nama in wisata_ntb_list:
    try:
        query = f"{nama}, Nusa Tenggara Barat, Indonesia"
        location = geolocator.geocode(query, exactly_one=True, addressdetails=True)
        if location:
            addr = location.raw.get('address', {})
            results.append({
                "nama_wisata": nama,
                "latitude": location.latitude,
                "longitude": location.longitude,
                "alamat": location.address,
                "provinsi": addr.get('state', ''),
                "kota_kabupaten": addr.get('city', '') or addr.get('county', '') or addr.get('region', '')
            })
            print(f"✓ Ditemukan: {nama}")
        else:
            results.append({
                "nama_wisata": nama,
                "latitude": None,
                "longitude": None,
                "alamat": "Not Found",
                "provinsi": "",
                "kota_kabupaten": ""
            })
            print(f"✗ Tidak ditemukan: {nama}")
    except Exception as e:
        results.append({
            "nama_wisata": nama,
            "latitude": None,
            "longitude": None,
            "alamat": f"Error: {e}",
            "provinsi": "",
            "kota_kabupaten": ""
        })
        print(f"⚠️ Error: {nama} - {e}")
    time.sleep(1)

df = pd.DataFrame(results)
df.to_csv("wisata_ntb_geocoding.csv", index=False)
print("✅ Data wisata NTB berhasil disimpan ke 'wisata_ntb_geocoding.csv'")
# Out:
# ✓ Ditemukan: Gunung Rinjani
# ✗ Tidak ditemukan: Danau Segara Anak
# ✓ Ditemukan: Pantai Senggigi
# ✓ Ditemukan: Pantai Kuta Lombok
# ✓ Ditemukan: Pantai Selong Belanak
# ✗ Tidak ditemukan: Pantai Mawun
# ✗ Tidak ditemukan: Pantai Tanjung Aan
# ✓ Ditemukan: Gili Trawangan
# ✓ Ditemukan: Gili Air
# ✓ Ditemukan: Gili Meno
# ✓ Ditemukan: Gili Nanggu
# ✓ Ditemukan: Gili Sulat
# ✓ Ditemukan: Gili Kedis
# ✓ Ditemukan: Gili Petelu
# ✗ Tidak ditemukan: Bukit Merese
# ✗ Tidak ditemukan: Bukit Pergasingan
# ✓ Ditemukan: Bukit Selong
# ✗ Tidak ditemukan: Air Terjun Tiu Kelep
# ✓ Ditemukan: Air Terjun Sendang Gile
# ✓ Ditemukan: Pantai Pink
# ✓ Ditemukan: Pantai Sire
# ✓ Ditemukan: Pantai Malimbu
# ✗ Tidak ditemukan: Pantai Bangko-Bangko
# ✓ Ditemukan: Pantai Nipah
# ✗ Tidak ditemukan: Pantai Batu Payung
# ✗ Tidak ditemukan: Pantai Mawun
# ✗ Tidak ditemukan: Pantai Gili Asahan
# ✓ Ditemukan: Pantai Sekotong
# ✗ Tidak ditemukan: Pantai Awang
# ✓ Ditemukan: Pantai Cemara
# ...

# %%
from geopy.geocoders import Nominatim
import pandas as pd
import time

wisata_ntt_list = [
    "Pulau Komodo", "Taman Nasional Komodo", "Pulau Rinca", "Pulau Padar", "Labuan Bajo",
    "Pantai Pink", "Pantai Merah Muda", "Pantai Kanawa", "Pantai Kelapa Lima", "Pantai Wainilu",
    "Danau Kelimutu", "Danau Tiga Warna Kelimutu", "Gunung Kelimutu", "Gunung Inerie",
    "Pantai Nembrala", "Pantai Nemberala", "Pantai Oesapa", "Pantai Lasiana", "Pantai Solo",
    "Air Terjun Oenesu", "Air Terjun Waimarang", "Air Terjun Oehala", "Air Terjun Sikulikap",
    "Air Terjun Tada", "Air Terjun Paga", "Air Terjun Ebulobo", "Air Terjun Fatumnasi",
    "Museum Negeri Nusa Tenggara Timur", "Museum Komodo", "Museum Kata", "Museum Sasando",
    "Pura Luhur Lingsar", "Pura Dalem Lewotobi", "Pura Segara", "Pura Air Panas",
    "Taman Nasional Laut Banda", "Taman Nasional Wae Wuul", "Taman Nasional Kelimutu",
    "Benteng Pendem Kupang", "Benteng Belgica", "Benteng Vredeburg", "Benteng Tolukko",
    "Benteng Kalamata", "Alun-Alun Kota Kupang", "Alun-Alun Kota Ende", "Alun-Alun Kota Maumere",
    "Pasar Adat Oeba", "Pasar Adat Kasih", "Pasar Adat Waiwerang", "Pasar Adat Bajawa",
    "Kampung Adat Bena", "Kampung Adat Wae Rebo", "Kampung Adat Luba", "Kampung Adat Lamalera",
    "Kampung Adat Naga", "Kampung Adat Ratenggaro", "Kampung Adat Praijing", "Kampung Adat Tololela",
    "Kampung Adat Tenda", "Kampung Adat Larantuka", "Kampung Adat Ebulobo", "Kampung Adat Nubia",
    "Pulau Semau", "Pulau Solor", "Pulau Flores", "Pulau Sumba", "Pulau Alor",
    "Pulau Rote", "Pulau Lembata", "Pulau Timor", "Pulau Adonara", "Pulau Pantar",
    "Pantai Mandorak", "Pantai Kolbano", "Pantai Pasir Putih Lewoleba", "Pantai Waikelo",
    "Pantai Watu Bela", "Pantai Mandon", "Pantai Mbawana", "Pantai Nangahure",
    "Bukit Cunca Wulang", "Bukit Wairinding", "Bukit Wolobobo", "Bukit Fatu Lobo",
    "Bukit Mbeliling", "Bukit Teletubbies", "Bukit Oelamasi", "Bukit Ruteng",
    "Goa Kristal Watumole", "Goa Liang Bua", "Goa Liang Nona", "Goa Runcing",
    "Goa Liang Lomba", "Goa Montong", "Goa Mata Gajah", "Goa Kelelawar",
    "Wisata Kuliner Kupang", "Wisata Kuliner Maumere", "Wisata Kuliner Ende",
    "Wisata Kuliner Larantuka", "Wisata Kuliner Sumba", "Wisata Kuliner Rote",
    "Wisata Edukasi Nusa Tenggara Timur", "Wisata Peternakan Nusa Tenggara Timur",
    "Wahana Keluarga Labuan Bajo", "Wahana Keluarga Kupang", "Wahana Keluarga Maumere"
]

geolocator = Nominatim(user_agent="wisata_ntt_geocoder")
results = []

for nama in wisata_ntt_list:
    try:
        query = f"{nama}, Nusa Tenggara Timur, Indonesia"
        location = geolocator.geocode(query, exactly_one=True, addressdetails=True)
        if location:
            addr = location.raw.get('address', {})
            results.append({
                "nama_wisata": nama,
                "latitude": location.latitude,
                "longitude": location.longitude,
                "alamat": location.address,
                "provinsi": addr.get('state', ''),
                "kota_kabupaten": addr.get('city', '') or addr.get('county', '') or addr.get('region', '')
            })
            print(f"✓ Ditemukan: {nama}")
        else:
            results.append({
                "nama_wisata": nama,
                "latitude": None,
                "longitude": None,
                "alamat": "Not Found",
                "provinsi": "",
                "kota_kabupaten": ""
            })
            print(f"✗ Tidak ditemukan: {nama}")
    except Exception as e:
        results.append({
            "nama_wisata": nama,
            "latitude": None,
            "longitude": None,
            "alamat": f"Error: {e}",
            "provinsi": "",
            "kota_kabupaten": ""
        })
        print(f"⚠️ Error: {nama} - {e}")
    time.sleep(1)

df = pd.DataFrame(results)
df.to_csv("wisata_ntt_geocoding.csv", index=False)
print("✅ Data wisata NTT berhasil disimpan ke 'wisata_ntt_geocoding.csv'")
# Out:
# ✓ Ditemukan: Pulau Komodo
# ✓ Ditemukan: Taman Nasional Komodo
# ✓ Ditemukan: Pulau Rinca
# ✓ Ditemukan: Pulau Padar
# ✓ Ditemukan: Labuan Bajo
# ✓ Ditemukan: Pantai Pink
# ✓ Ditemukan: Pantai Merah Muda
# ✗ Tidak ditemukan: Pantai Kanawa
# ✗ Tidak ditemukan: Pantai Kelapa Lima
# ✗ Tidak ditemukan: Pantai Wainilu
# ✗ Tidak ditemukan: Danau Kelimutu
# ✗ Tidak ditemukan: Danau Tiga Warna Kelimutu
# ✓ Ditemukan: Gunung Kelimutu
# ✓ Ditemukan: Gunung Inerie
# ✗ Tidak ditemukan: Pantai Nembrala
# ✓ Ditemukan: Pantai Nemberala
# ✓ Ditemukan: Pantai Oesapa
# ✓ Ditemukan: Pantai Lasiana
# ✗ Tidak ditemukan: Pantai Solo
# ✗ Tidak ditemukan: Air Terjun Oenesu
# ✓ Ditemukan: Air Terjun Waimarang
# ✗ Tidak ditemukan: Air Terjun Oehala
# ✗ Tidak ditemukan: Air Terjun Sikulikap
# ✗ Tidak ditemukan: Air Terjun Tada
# ✗ Tidak ditemukan: Air Terjun Paga
# ✗ Tidak ditemukan: Air Terjun Ebulobo
# ✗ Tidak ditemukan: Air Terjun Fatumnasi
# ✗ Tidak ditemukan: Museum Negeri Nusa Tenggara Timur
# ...

# %%
from geopy.geocoders import Nominatim
import pandas as pd
import time

wisata_kalbar_list = [
    "Taman Nasional Danau Sentarum", "Taman Nasional Bukit Baka Bukit Raya", "Gunung Palung National Park",
    "Danau Sentarum", "Danau Jempang", "Danau Kelam", "Pantai Temajuk", "Pantai Pasir Panjang",
    "Pantai Tanjung Bajau", "Pantai Tanjung Datuk", "Pantai Batu Ampar", "Pantai Air Mati",
    "Pantai Pulau Lemukutan", "Pantai Pulau Karimata", "Pantai Pulau Maya", "Pulau Karimata",
    "Pulau Lemukutan", "Pulau Randayan", "Pulau Cempedak", "Pulau Matahari",
    "Pulau Sedauk", "Pulau Tempurung", "Pulau Enkuno", "Pulau Selimau", "Pulau Segamai",
    "Gunung Raya", "Gunung Betung", "Gunung Saran", "Gunung Pasi", "Gunung Liang Krang",
    "Air Terjun Temajuk", "Air Terjun Sei Lembu", "Air Terjun Air Terantang", "Air Terjun Sungai Tuah",
    "Air Terjun Lembah Harau", "Air Terjun Embun Pelangi", "Air Terjun Gua Harimau",
    "Museum Negeri Pontianak", "Museum Kalimantan Barat", "Museum Kapuas", "Museum Bahari Pontianak",
    "Museum Tradisional Dayak", "Benteng Kuto Besak", "Benteng Soekadana", "Benteng Tebas",
    "Benteng Kayong", "Keraton Kadriyah", "Keraton Kadriah", "Taman Alun Kapuas", "Taman Alun Kapuas Pontianak",
    "Taman Burung Pontianak", "Kebun Raya Pontianak", "Pasar Flamboyan", "Pasar Tengah",
    "Pasar Souvenir Pontianak", "Pasar Tanjung Raya", "Pasar Keramat", "Pasar Sanggau",
    "Pasar Kapuas Hulu", "Pasar Sintang", "Kampung Dayak", "Kampung Melayu",
    "Kampung Lintas Batas", "Kampung Hulu", "Kampung Sadap", "Kampung Sebangkau",
    "Pulau Lemukutan", "Pulau Randayan", "Pulau Sekatung", "Pulau Bangkalan", "Pulau Temajuk",
    "Taman Wisata Alam Gunung Raya", "Taman Wisata Alam Sungai Landak", "Taman Wisata Alam Gunung Saran",
    "Bukit Kelam", "Bukit Saran", "Bukit Baka", "Bukit Raya", "Bukit Jaya",
    "Wahana Bermain Happy World", "Wahana Bermain Waterboom Singkawang", "Taman Kota Singkawang",
    "Taman Kota Pontianak", "Taman Wisata Alam Danau Sentarum", "Taman Wisata Alam Sungai Melawi",
    "Goa Batu Ampar", "Goa Batu Lawang", "Goa Batu Hiu", "Goa Batu Lumpang",
    "Wisata Kuliner Pontianak", "Wisata Kuliner Singkawang", "Wisata Kuliner Sintang",
    "Wisata Kuliner Ketapang", "Wisata Kuliner Mempawah", "Wisata Kuliner Sambas",
    "Wisata Edukasi Kalimantan Barat", "Wisata Edukasi Pontianak", "Wisata Edukasi Singkawang",
    "Wahana Keluarga Pontianak", "Wahana Keluarga Singkawang", "Wahana Keluarga Sintang",
    "Ayani Mega Mall Pontianak", "Mall Kapuas Indah Pontianak", "Pontianak Mall",
    "Singkawang Central Plaza", "Mal Ciputra Pontianak", "Ramayana Mall Pontianak",
    "Mal Kartini Pontianak", "Mal Mega Mall Sintang"
]

geolocator = Nominatim(user_agent="wisata_kalbar_geocoder")
results = []

for nama in wisata_kalbar_list:
    try:
        query = f"{nama}, Kalimantan Barat, Indonesia"
        location = geolocator.geocode(query, exactly_one=True, addressdetails=True)
        if location:
            addr = location.raw.get('address', {})
            results.append({
                "nama_wisata": nama,
                "latitude": location.latitude,
                "longitude": location.longitude,
                "alamat": location.address,
                "provinsi": addr.get('state', ''),
                "kota_kabupaten": addr.get('city', '') or addr.get('county', '') or addr.get('region', '')
            })
            print(f"✓ Ditemukan: {nama}")
        else:
            results.append({
                "nama_wisata": nama,
                "latitude": None,
                "longitude": None,
                "alamat": "Not Found",
                "provinsi": "",
                "kota_kabupaten": ""
            })
            print(f"✗ Tidak ditemukan: {nama}")
    except Exception as e:
        results.append({
            "nama_wisata": nama,
            "latitude": None,
            "longitude": None,
            "alamat": f"Error: {e}",
            "provinsi": "",
            "kota_kabupaten": ""
        })
        print(f"⚠️ Error: {nama} - {e}")
    time.sleep(1)

df = pd.DataFrame(results)
df.to_csv("wisata_kalbar_geocoding.csv", index=False)
print("✅ Data wisata Kalimantan Barat berhasil disimpan ke 'wisata_kalbar_geocoding.csv'")
# Out:
# ✓ Ditemukan: Taman Nasional Danau Sentarum
# ✓ Ditemukan: Taman Nasional Bukit Baka Bukit Raya
# ✓ Ditemukan: Gunung Palung National Park
# ✓ Ditemukan: Danau Sentarum
# ✗ Tidak ditemukan: Danau Jempang
# ✗ Tidak ditemukan: Danau Kelam
# ✗ Tidak ditemukan: Pantai Temajuk
# ✗ Tidak ditemukan: Pantai Pasir Panjang
# ✗ Tidak ditemukan: Pantai Tanjung Bajau
# ✗ Tidak ditemukan: Pantai Tanjung Datuk
# ✗ Tidak ditemukan: Pantai Batu Ampar
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=Pantai+Air+Mati%2C+Kalimantan+Barat%2C+Indonesia&format=json&limit=1&addressdetails=1
# ✗ Tidak ditemukan: Pantai Air Mati
# ✗ Tidak ditemukan: Pantai Pulau Lemukutan
# ✗ Tidak ditemukan: Pantai Pulau Karimata
# ✗ Tidak ditemukan: Pantai Pulau Maya
# ✓ Ditemukan: Pulau Karimata
# ...

# %%
from geopy.geocoders import Nominatim
import pandas as pd
import time

wisata_kalteng_list = [
    "Taman Nasional Tanjung Puting", "Taman Nasional Bukit Baka Bukit Raya", "Danau Seran",
    "Danau Sebangau", "Danau Sembuluh", "Danau Pahlawan", "Pantai Palangkaraya", "Pantai Tangkiling",
    "Pantai Teluk Kalabakan", "Pantai Murung Raya", "Pantai Batu Kayu", "Pantai Sidoarjo",
    "Air Terjun Mandalika", "Air Terjun Palingkau", "Air Terjun Batu Ampar", "Air Terjun Belantikan",
    "Air Terjun Hutan Panjang", "Air Terjun Buntok", "Air Terjun Sungai Rajang", "Museum Balanga",
    "Museum Palangka Raya", "Museum Taman Rekreasi", "Museum Kayu Pahlawan", "Museum Kalimantan Tengah",
    "Taman Kota Palangkaraya", "Alun-Alun Palangkaraya", "Monumen Palangkaraya", "Monumen Warisan Budaya",
    "Monumen Kalteng", "Kampung Adat Dayak", "Kampung Tumbang Nusa", "Kampung Bangka Lima", "Kampung Sawit",
    "Kampung Melayu Borneo", "Kampung Pulo", "Kampung Serampung", "Kampung Tumbang Akeh", "Kampung Lebak",
    "Gunung Sebangau", "Gunung Satria", "Gunung Tangkiling", "Gunung Pangalengan", "Gunung Betung",
    "Gunung Lawa", "Gunung Tarantang", "Bukit Batu", "Bukit Barisan", "Bukit Sendang",
    "Kebun Raya Palangkaraya", "Kebun Raya Bukit Raya", "Pasar Palangkaraya", "Pasar Suka Raya",
    "Pasar Kota Barito", "Pasar Benangin", "Pasar Kasongan", "Pasar Arinda", "Pasar Kuala Pembuang",
    "Pulau Mandai", "Pulau Bunti", "Pulau Lundu", "Pulau Kahayan", "Pulau Katingan",
    "Pulau Kuning", "Pulau Pahang", "Pulau Madura", "Pulau Kakap", "Pulau Sumber",
    "Kebun Kakao Palangkaraya", "Kebun Kelapa Sawit", "Kebun Coklat Kalimantan", "Wahana Permainan Palangkaraya",
    "Wahana Keluarga Palangkaraya", "Goa Batu Kalimantan Tengah", "Goa Buntu", "Goa Sintang",
    "Goa Senun", "Goa Rajang", "Goa Labuan Rawa", "Goa Batu Besar", "Goa Batu Tiga",
    "Wahana Wisata Alam Palangkaraya", "Wahana Tempat Wisata Kalimantan Tengah", "Wahana Edukasi Kalimantan Tengah",
    "Wahana Air Danau Sentarum", "Wahana Air Terjun", "Wisata Kuliner Kalimantan Tengah", "Wisata Kuliner Palangkaraya",
    "Wisata Kuliner Rantau", "Wisata Kuliner Tumbang Nusa", "Wisata Kuliner Kota Barito", "Wisata Kuliner Kasongan",
    "Wisata Kuliner Kahayan", "Wisata Kuliner Kuala Pembuang", "Wisata Kuliner Sabang", "Wisata Kuliner Sungai Rajang",
    "Palangka Raya Mall", "Matahari Mall Palangka Raya", "Pasar Swalayan Palangka Raya",
    "Pasar Induk Palangka Raya", "Metro Pasar Modern Palangka Raya"
]

geolocator = Nominatim(user_agent="wisata_kalteng_geocoder")
results = []

for nama in wisata_kalteng_list:
    try:
        query = f"{nama}, Kalimantan Tengah, Indonesia"
        location = geolocator.geocode(query, exactly_one=True, addressdetails=True)
        if location:
            addr = location.raw.get('address', {})
            results.append({
                "nama_wisata": nama,
                "latitude": location.latitude,
                "longitude": location.longitude,
                "alamat": location.address,
                "provinsi": addr.get('state', ''),
                "kota_kabupaten": addr.get('city', '') or addr.get('county', '') or addr.get('region', '')
            })
            print(f"✓ Ditemukan: {nama}")
        else:
            results.append({
                "nama_wisata": nama,
                "latitude": None,
                "longitude": None,
                "alamat": "Not Found",
                "provinsi": "",
                "kota_kabupaten": ""
            })
            print(f"✗ Tidak ditemukan: {nama}")
    except Exception as e:
        results.append({
            "nama_wisata": nama,
            "latitude": None,
            "longitude": None,
            "alamat": f"Error: {e}",
            "provinsi": "",
            "kota_kabupaten": ""
        })
        print(f"⚠️ Error: {nama} - {e}")
    time.sleep(1)

df = pd.DataFrame(results)
df.to_csv("wisata_kalteng_geocoding.csv", index=False)
print("✅ Data wisata Kalimantan Tengah berhasil disimpan ke 'wisata_kalteng_geocoding.csv'")
# Out:
# ✓ Ditemukan: Taman Nasional Tanjung Puting
# ✓ Ditemukan: Taman Nasional Bukit Baka Bukit Raya
# ✗ Tidak ditemukan: Danau Seran
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=Danau+Sebangau%2C+Kalimantan+Tengah%2C+Indonesia&format=json&limit=1&addressdetails=1
# ✓ Ditemukan: Danau Sebangau
# ✓ Ditemukan: Danau Sembuluh
# ✗ Tidak ditemukan: Danau Pahlawan
# ✗ Tidak ditemukan: Pantai Palangkaraya
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=Pantai+Tangkiling%2C+Kalimantan+Tengah%2C+Indonesia&format=json&limit=1&addressdetails=1
# ...

# %%
from geopy.geocoders import Nominatim
import pandas as pd
import time

wisata_kaltim_list = [
    "Taman Nasional Kutai", "Taman Nasional Kayan Mentarang", "Pantai Tenggelam",
    "Pantai Melawai", "Pantai Tanjung Jumlai", "Pantai Teluk Lombok", "Pantai Pasir Hitam",
    "Pantai Tanah Merah", "Pantai Bontang", "Pulau Derawan", "Pulau Maratua", "Pulau Sangalaki",
    "Pulau Kakaban", "Pulau Panjang", "Pulau Samama", "Pulau Berau", "Pulau Tidung",
    "Gunung Meratus", "Gunung Kejora", "Gunung Bromo", "Gunung Semeru", "Gunung Siau",
    "Air Terjun Pelipisan", "Air Terjun Meratan", "Air Terjun Pendarata", "Air Terjun Selat",
    "Air Terjun Rawa", "Air Terjun Sepaku", "Air Terjun Labuan", "Air Terjun Manggar",
    "Taman Nasional Kutai", "Taman Wisata Alam Kutai", "Museum Mulawarman", "Museum Tanjung Redeb",
    "Museum Batu", "Museum Taman Nasional Kutai", "Monumen Tugu Borneo", "Monumen Kaltim",
    "Kampung Adat Dayak", "Kampung Bugis", "Kampung Melayu", "Kampung Bontang", "Kampung Luwu",
    "Kampung Rawa", "Kampung Berau", "Kampung Samarinda", "Kampung Teluk", "Kampung Teluk Manau",
    "Jembatan Mahakam", "Jembatan Tenggarong", "Jembatan Samarinda", "Kebun Raya Samarinda",
    "Kebun Raya Berau", "Kebun Raya Luwu", "Pasar Tenggarong", "Pasar Tradisional Samarinda",
    "Pasar Senyiur", "Pasar Bontang", "Pasar Ikan Borneo", "Pulau Karang", "Pulau Derawan",
    "Pulau Maratua", "Pulau Sangalaki", "Pulau Kakaban", "Pulau Panjang", "Pulau Samama",
    "Bukit Sempit", "Bukit Taman Wisata Alam", "Bukit Raya", "Bukit Sesar", "Bukit Semut",
    "Kebun Kopi Berau", "Kebun Kakao Samarinda", "Taman Kota Samarinda", "Taman Kota Bontang",
    "Taman Wisata Alam Tanah Merah", "Goa Panggung", "Goa Murung Raya", "Goa Kecil", "Goa Berau",
    "Goa Batu", "Goa Semut", "Goa Batu", "Goa Sempit", "Goa Bukit Sempit", "Wisata Kuliner Samarinda",
    "Wisata Kuliner Bontang", "Wisata Kuliner Berau", "Wisata Kuliner Kutai", "Wisata Kuliner Tenggarong",
    "Wisata Kuliner Tanah Merah", "Wisata Kuliner Teluk", "Wisata Kuliner Sempit", "Wahana Keluarga Samarinda",
    "Wahana Keluarga Bontang", "Wahana Keluarga Berau", "Wahana Keluarga Tenggarong", "Wahana Wisata Alam Samarinda",
    "Wahana Wisata Alam Bontang", "Wahana Edukasi Kalimantan Timur", "Wahana Edukasi Samarinda",
    "Wahana Edukasi Bontang", "Wahana Edukasi Berau", "Wahana Alam Samarinda", "Wahana Alam Bontang",
    "Mall Samarinda Central Plaza", "Big Mall Balikpapan", "Mall Mesra Samarinda",
    "Plaza Balikpapan", "Mall Lembuswana Samarinda", "Mall Mahkota Balikpapan",
    "Mall Plaza Balikpapan", "Mall E-Walk Samarinda"
]

geolocator = Nominatim(user_agent="wisata_kaltim_geocoder")
results = []

for nama in wisata_kaltim_list:
    try:
        query = f"{nama}, Kalimantan Timur, Indonesia"
        location = geolocator.geocode(query, exactly_one=True, addressdetails=True)
        if location:
            addr = location.raw.get('address', {})
            results.append({
                "nama_wisata": nama,
                "latitude": location.latitude,
                "longitude": location.longitude,
                "alamat": location.address,
                "provinsi": addr.get('state', ''),
                "kota_kabupaten": addr.get('city', '') or addr.get('county', '') or addr.get('region', '')
            })
            print(f"✓ Ditemukan: {nama}")
        else:
            results.append({
                "nama_wisata": nama,
                "latitude": None,
                "longitude": None,
                "alamat": "Not Found",
                "provinsi": "",
                "kota_kabupaten": ""
            })
            print(f"✗ Tidak ditemukan: {nama}")
    except Exception as e:
        results.append({
            "nama_wisata": nama,
            "latitude": None,
            "longitude": None,
            "alamat": f"Error: {e}",
            "provinsi": "",
            "kota_kabupaten": ""
        })
        print(f"⚠️ Error: {nama} - {e}")
    time.sleep(1)

df = pd.DataFrame(results)
df.to_csv("wisata_kaltim_geocoding.csv", index=False)
print("✅ Data wisata Kalimantan Timur berhasil disimpan ke 'wisata_kaltim_geocoding.csv'")
# Out:
# ✓ Ditemukan: Taman Nasional Kutai
# ✗ Tidak ditemukan: Taman Nasional Kayan Mentarang
# ✗ Tidak ditemukan: Pantai Tenggelam
# ✓ Ditemukan: Pantai Melawai
# ✗ Tidak ditemukan: Pantai Tanjung Jumlai
# ✓ Ditemukan: Pantai Teluk Lombok
# ✗ Tidak ditemukan: Pantai Pasir Hitam
# ✓ Ditemukan: Pantai Tanah Merah
# ✓ Ditemukan: Pantai Bontang
# ✓ Ditemukan: Pulau Derawan
# ✓ Ditemukan: Pulau Maratua
# ✓ Ditemukan: Pulau Sangalaki
# ✓ Ditemukan: Pulau Kakaban
# ✓ Ditemukan: Pulau Panjang
# ✓ Ditemukan: Pulau Samama
# ✓ Ditemukan: Pulau Berau
# ✓ Ditemukan: Pulau Tidung
# ✓ Ditemukan: Gunung Meratus
# ✗ Tidak ditemukan: Gunung Kejora
# ✓ Ditemukan: Gunung Bromo
# ✓ Ditemukan: Gunung Semeru
# ✗ Tidak ditemukan: Gunung Siau
# ✗ Tidak ditemukan: Air Terjun Pelipisan
# ✗ Tidak ditemukan: Air Terjun Meratan
# ✗ Tidak ditemukan: Air Terjun Pendarata
# ✗ Tidak ditemukan: Air Terjun Selat
# ✗ Tidak ditemukan: Air Terjun Rawa
# ✗ Tidak ditemukan: Air Terjun Sepaku
# ✗ Tidak ditemukan: Air Terjun Labuan
# ...

# %%
from geopy.geocoders import Nominatim
import pandas as pd
import time

wisata_kaltara_list = [
    "Taman Nasional Kayan Mentarang", "Pulau Maratua", "Pulau Derawan", "Pulau Kakaban", "Pulau Sangalaki",
    "Pulau Tidung", "Pantai Tanah Merah", "Pantai Bintulu", "Pantai Sekongkang", "Air Terjun Tanjung Batu",
    "Air Terjun Luwuk", "Air Terjun Ngelai", "Air Terjun Semut", "Museum Kalimantan Utara",
    "Monumen Tugu Kaltara", "Bukit Payung", "Bukit Batu", "Bukit Sempit", "Gunung Baluran",
    "Gunung Tangkiling", "Kampung Dayak", "Kampung Melayu", "Kampung Bugis", "Kampung Pulo",
    "Kampung Bugis Tanah Merah", "Gunung Meratus", "Gunung Siau", "Gunung Tarantang", "Taman Alam Borneo",
    "Taman Wisata Alam Pampang", "Kebun Raya Kalimantan Utara", "Pasar Tradisional Tanah Merah",
    "Pasar Arinda", "Pasar Tradisional Kota Tarakan", "Kebun Kopi Kalimantan", "Kebun Kelapa Sawit",
    "Taman Kota Tarakan", "Taman Kota Bulungan", "Taman Kota Berau", "Wahana Wisata Alam Tanah Merah",
    "Wahana Wisata Alam Bulungan", "Wahana Keluarga Samarinda", "Wahana Tempat Wisata Alam Kalimantan Utara",
    "Pulau Karang", "Pulau Tidung", "Bukit Sempit", "Kebun Kakao Tarakan", "Pasar Kota Tarakan", "Taman Wisata Alam Kaltara"
]

geolocator = Nominatim(user_agent="wisata_kaltara_geocoder")
results = []

for nama in wisata_kaltara_list:
    try:
        query = f"{nama}, Kalimantan Utara, Indonesia"
        location = geolocator.geocode(query, exactly_one=True, addressdetails=True)
        if location:
            addr = location.raw.get('address', {})
            results.append({
                "nama_wisata": nama,
                "latitude": location.latitude,
                "longitude": location.longitude,
                "alamat": location.address,
                "provinsi": addr.get('state', ''),
                "kota_kabupaten": addr.get('city', '') or addr.get('county', '') or addr.get('region', '')
            })
            print(f"✓ Ditemukan: {nama}")
        else:
            results.append({
                "nama_wisata": nama,
                "latitude": None,
                "longitude": None,
                "alamat": "Not Found",
                "provinsi": "",
                "kota_kabupaten": ""
            })
            print(f"✗ Tidak ditemukan: {nama}")
    except Exception as e:
        results.append({
            "nama_wisata": nama,
            "latitude": None,
            "longitude": None,
            "alamat": f"Error: {e}",
            "provinsi": "",
            "kota_kabupaten": ""
        })
        print(f"⚠️ Error: {nama} - {e}")
    time.sleep(1)

df = pd.DataFrame(results)
df.to_csv("wisata_kaltara_geocoding.csv", index=False)
print("✅ Data wisata Kalimantan Utara berhasil disimpan ke 'wisata_kaltara_geocoding.csv'")
# Out:
# ✓ Ditemukan: Taman Nasional Kayan Mentarang
# ✗ Tidak ditemukan: Pulau Maratua
# ✗ Tidak ditemukan: Pulau Derawan
# ✗ Tidak ditemukan: Pulau Kakaban
# ✗ Tidak ditemukan: Pulau Sangalaki
# ✓ Ditemukan: Pulau Tidung
# ✗ Tidak ditemukan: Pantai Tanah Merah
# ✗ Tidak ditemukan: Pantai Bintulu
# ✗ Tidak ditemukan: Pantai Sekongkang
# ✗ Tidak ditemukan: Air Terjun Tanjung Batu
# ✗ Tidak ditemukan: Air Terjun Luwuk
# ✗ Tidak ditemukan: Air Terjun Ngelai
# ✗ Tidak ditemukan: Air Terjun Semut
# ✓ Ditemukan: Museum Kalimantan Utara
# ✗ Tidak ditemukan: Monumen Tugu Kaltara
# ✗ Tidak ditemukan: Bukit Payung
# ✗ Tidak ditemukan: Bukit Batu
# ✗ Tidak ditemukan: Bukit Sempit
# ...

# %%
from geopy.geocoders import Nominatim
import pandas as pd
import time

# List wisata Sulawesi Utara
wisata_sulut_list = [
    "Taman Nasional Bunaken", "Gunung Klabat", "Danau Tondano", "Pantai Malalayang", "Pantai Paniki",
    "Pantai Bunaken", "Pantai Lihaga", "Taman Laut Bunaken", "Air Terjun Tumpa", "Air Terjun Dua Saudara",
    "Air Terjun Lembean", "Monumen Peace", "Museum Negeri Sulawesi Utara", "Kota Manado", "Bukit Doa Tomohon",
    "Bukit Kasih Kanonang", "Taman Wisata Alam Tangkoko", "Kebun Raya Tomohon", "Museum Purbakala Bentenan",
    "Candi Hindu Malalayang", "Masjid Al-Makmur Manado", "Gua Sion Tomohon", "Gua Maria Kanonang",
    "Pura Jagatnatha Manado", "Gua Luweng Sewa", "Alun-alun Kota Manado", "Wakatobi Diving Resort",
    "Kota Tua Manado", "Pasar Bersehati", "Pasar 45 Manado", "Taman Cagar Alam Gunung Ambang", "Bunaken Marine Park",
    "Taman Laut Wakatobi", "Pantai Paal", "Pantai Minahasa", "Danau Linow", "Gua Maria Pontianak",
    "Pantai Batu Pinagut", "Pulau Siau", "Pulau Lembeh", "Pulau Bangka", "Pantai Malalayang", "Taman Laut"
]

# Initialize geolocator
geolocator = Nominatim(user_agent="wisata_sulut_geocoder")
results = []

# Geocode each wisata name
for nama in wisata_sulut_list:
    try:
        query = f"{nama}, Sulawesi Utara, Indonesia"
        location = geolocator.geocode(query, exactly_one=True, addressdetails=True)
        if location:
            addr = location.raw.get('address', {})
            results.append({
                "nama_wisata": nama,
                "latitude": location.latitude,
                "longitude": location.longitude,
                "alamat": location.address,
                "provinsi": addr.get('state', ''),
                "kota_kabupaten": addr.get('city', '') or addr.get('county', '') or addr.get('region', '')
            })
            print(f"✓ Ditemukan: {nama}")
        else:
            results.append({
                "nama_wisata": nama,
                "latitude": None,
                "longitude": None,
                "alamat": "Not Found",
                "provinsi": "",
                "kota_kabupaten": ""
            })
            print(f"✗ Tidak ditemukan: {nama}")
    except Exception as e:
        results.append({
            "nama_wisata": nama,
            "latitude": None,
            "longitude": None,
            "alamat": f"Error: {e}",
            "provinsi": "",
            "kota_kabupaten": ""
        })
        print(f"⚠️ Error: {nama} - {e}")
    time.sleep(1)  # Delay to avoid rate limiting

# Create DataFrame and save
df = pd.DataFrame(results)
df.to_csv("wisata_sulut_geocoding.csv", index=False)
print("✅ Data wisata Sulawesi Utara berhasil disimpan ke 'wisata_sulut_geocoding.csv'")
# Out:
# ✓ Ditemukan: Taman Nasional Bunaken
# ✓ Ditemukan: Gunung Klabat
# ✓ Ditemukan: Danau Tondano
# ✓ Ditemukan: Pantai Malalayang
# ✗ Tidak ditemukan: Pantai Paniki
# ✓ Ditemukan: Pantai Bunaken
# ✗ Tidak ditemukan: Pantai Lihaga
# ✗ Tidak ditemukan: Taman Laut Bunaken
# ✗ Tidak ditemukan: Air Terjun Tumpa
# ✗ Tidak ditemukan: Air Terjun Dua Saudara
# ✗ Tidak ditemukan: Air Terjun Lembean
# ✗ Tidak ditemukan: Monumen Peace
# ✓ Ditemukan: Museum Negeri Sulawesi Utara
# ✓ Ditemukan: Kota Manado
# ✓ Ditemukan: Bukit Doa Tomohon
# ✗ Tidak ditemukan: Bukit Kasih Kanonang
# ✗ Tidak ditemukan: Taman Wisata Alam Tangkoko
# ✗ Tidak ditemukan: Kebun Raya Tomohon
# ✗ Tidak ditemukan: Museum Purbakala Bentenan
# ✗ Tidak ditemukan: Candi Hindu Malalayang
# ✗ Tidak ditemukan: Masjid Al-Makmur Manado
# ✗ Tidak ditemukan: Gua Sion Tomohon
# ✗ Tidak ditemukan: Gua Maria Kanonang
# ✗ Tidak ditemukan: Pura Jagatnatha Manado
# ✗ Tidak ditemukan: Gua Luweng Sewa
# ✗ Tidak ditemukan: Alun-alun Kota Manado
# ...

# %%
from geopy.geocoders import Nominatim
import pandas as pd
import time

# List wisata Gorontalo
wisata_gorontalo_list = [
    "Taman Nasional Bogani Nani Wartabone", "Pantai Olele", "Danau Limboto", "Pantai Minanga", "Air Terjun Bidadari",
    "Air Terjun Hiu", "Pantai Panipi", "Pulau Cinta", "Monumen Nani Wartabone", "Masjid Agung Gorontalo",
    "Kota Tua Gorontalo", "Pantai Dulupi", "Pulau Saronde", "Taman Laut Saronde", "Gua Pinus", "Bukit Layang",
    "Taman Wisata Alam Tangkoko", "Kebun Raya Gorontalo", "Museum Purbakala Bulango", "Candi Hindu Malalayang",
    "Gua Sion Tomohon", "Pura Jagatnatha Manado", "Alun-alun Kota Manado", "Kampung Adat Dulupi", "Pantai Tabulo",
    "Pasar Sentral Gorontalo", "Gua Luweng Sewa", "Pantai Batu Dinding", "Pulau Siauw", "Gua Maria Kanonang",
    "Pantai Rontu", "Puncak Togean", "Taman Cagar Alam Gunung Ambang", "Taman Laut Wakatobi", "Bukit Kasih Kanonang",
    "Danau Tontumo", "Taman Purbakala Bentenan", "Pantai Tabulo", "Pantai Minahasa", "Pulau Saronde", "Pantai Panipi",
    "Pantai Dulupi", "Bukit Kawua", "Pulau Lembeh", "Pantai Batu Pinagut", "Air Terjun Tinali", "Pantai Batu Pinagut"
]

# Initialize geolocator
geolocator = Nominatim(user_agent="wisata_gorontalo_geocoder")
results = []

# Geocode each wisata name
for nama in wisata_gorontalo_list:
    try:
        query = f"{nama}, Gorontalo, Indonesia"
        location = geolocator.geocode(query, exactly_one=True, addressdetails=True)
        if location:
            addr = location.raw.get('address', {})
            results.append({
                "nama_wisata": nama,
                "latitude": location.latitude,
                "longitude": location.longitude,
                "alamat": location.address,
                "provinsi": addr.get('state', ''),
                "kota_kabupaten": addr.get('city', '') or addr.get('county', '') or addr.get('region', '')
            })
            print(f"✓ Ditemukan: {nama}")
        else:
            results.append({
                "nama_wisata": nama,
                "latitude": None,
                "longitude": None,
                "alamat": "Not Found",
                "provinsi": "",
                "kota_kabupaten": ""
            })
            print(f"✗ Tidak ditemukan: {nama}")
    except Exception as e:
        results.append({
            "nama_wisata": nama,
            "latitude": None,
            "longitude": None,
            "alamat": f"Error: {e}",
            "provinsi": "",
            "kota_kabupaten": ""
        })
        print(f"⚠️ Error: {nama} - {e}")
    time.sleep(1)  # Delay to avoid rate limiting

# Create DataFrame and save
df = pd.DataFrame(results)
df.to_csv("wisata_gorontalo_geocoding.csv", index=False)
print("✅ Data wisata Gorontalo berhasil disimpan ke 'wisata_gorontalo_geocoding.csv'")
# Out:
# ✓ Ditemukan: Taman Nasional Bogani Nani Wartabone
# ✗ Tidak ditemukan: Pantai Olele
# ✓ Ditemukan: Danau Limboto
# ✗ Tidak ditemukan: Pantai Minanga
# ✗ Tidak ditemukan: Air Terjun Bidadari
# ✗ Tidak ditemukan: Air Terjun Hiu
# ✗ Tidak ditemukan: Pantai Panipi
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=Pulau+Cinta%2C+Gorontalo%2C+Indonesia&format=json&limit=1&addressdetails=1
# ✗ Tidak ditemukan: Pulau Cinta
# ✓ Ditemukan: Monumen Nani Wartabone
# ✓ Ditemukan: Masjid Agung Gorontalo
# ✗ Tidak ditemukan: Kota Tua Gorontalo
# ✗ Tidak ditemukan: Pantai Dulupi
# ✗ Tidak ditemukan: Pulau Saronde
# ✗ Tidak ditemukan: Taman Laut Saronde
# ✗ Tidak ditemukan: Gua Pinus
# ✗ Tidak ditemukan: Bukit Layang
# ✗ Tidak ditemukan: Taman Wisata Alam Tangkoko
# ...

# %%
from geopy.geocoders import Nominatim
import pandas as pd
import time

# Daftar wisata Sulawesi Tengah
wisata_sulteng_list = [
    "Taman Nasional Lore Lindu", "Pantai Taipa", "Pantai Palu", "Pantai Tanjung Karang",
    "Gunung Gawalise", "Air Terjun Sapu Lidi", "Air Terjun Rarampa", "Air Terjun Saluka",
    "Kampung Adat Kaili", "Kampung Adat Luwuk", "Monumen Palu", "Taman Wisata Alam Lindu",
    "Taman Nasional Bunaken", "Kebun Raya Palu", "Kebun Teh Dataran Tinggi", "Mata Air Tonda",
    "Gunung Tondano", "Goa Ria", "Taman Kota Palu", "Museum Palu", "Museum Luwuk",
    "Mall Tatura", "Palu Grand Mall", "Mall Mega Palu", "Mall Luwuk", "Mega Mall Ternate",
    "Plaza Palu", "Sentral Plaza Palu", "Palopo City Mall", "Mall Sulteng", "Central Plaza Palu",
    "Bukit Nona", "Bukit Timang", "Taman Kota Palu", "Goa Sapi", "Goa Rahmat", "Pasar Tradisional Palu",
    "Pasar Malam Palu", "Pasar Luwuk", "Candi Palu", "Wahana Keluarga Palu", "Wahana Keluarga Luwuk",
    "Wahana Wisata Alam Palu", "Wahana Wisata Alam Luwuk", "Pantai Gorontalo", "Pantai Tanpa Karang",
    "Kampung Wisata Tontu", "Kampung Tanjung Kuta", "Kampung Sumber", "Taman Alam Luwuk", "Bukit Mouton"
]

# Inisialisasi geolocator
geolocator = Nominatim(user_agent="wisata_geocoder_sulteng")
results = []

# Proses geocoding
for nama in wisata_sulteng_list:
    try:
        query = f"{nama}, Sulawesi Tengah, Indonesia"
        location = geolocator.geocode(query, exactly_one=True, addressdetails=True)
        if location:
            addr = location.raw.get('address', {})
            results.append({
                "nama_wisata": nama,
                "latitude": location.latitude,
                "longitude": location.longitude,
                "alamat": location.address,
                "provinsi": addr.get('state', ''),
                "kota_kabupaten": addr.get('city', '') or addr.get('county', '') or addr.get('region', '')
            })
            print(f"✓ Ditemukan: {nama}")
        else:
            results.append({
                "nama_wisata": nama,
                "latitude": None,
                "longitude": None,
                "alamat": "Not Found",
                "provinsi": "",
                "kota_kabupaten": ""
            })
            print(f"✗ Tidak ditemukan: {nama}")
    except Exception as e:
        results.append({
            "nama_wisata": nama,
            "latitude": None,
            "longitude": None,
            "alamat": f"Error: {e}",
            "provinsi": "",
            "kota_kabupaten": ""
        })
        print(f"⚠️ Error: {nama} - {e}")
    time.sleep(1)

df = pd.DataFrame(results)
df.to_csv("wisata_sulteng_with_mall.csv", index=False)
print("✅ Data wisata Sulawesi Tengah dengan Mall berhasil disimpan ke 'wisata_sulteng_with_mall.csv'")
# Out:
# ✓ Ditemukan: Taman Nasional Lore Lindu
# ✗ Tidak ditemukan: Pantai Taipa
# ✓ Ditemukan: Pantai Palu
# ✗ Tidak ditemukan: Pantai Tanjung Karang
# ✗ Tidak ditemukan: Gunung Gawalise
# ✗ Tidak ditemukan: Air Terjun Sapu Lidi
# ✗ Tidak ditemukan: Air Terjun Rarampa
# ✗ Tidak ditemukan: Air Terjun Saluka
# ✗ Tidak ditemukan: Kampung Adat Kaili
# ✗ Tidak ditemukan: Kampung Adat Luwuk
# ✗ Tidak ditemukan: Monumen Palu
# ✗ Tidak ditemukan: Taman Wisata Alam Lindu
# ✗ Tidak ditemukan: Taman Nasional Bunaken
# ✗ Tidak ditemukan: Kebun Raya Palu
# ✗ Tidak ditemukan: Kebun Teh Dataran Tinggi
# ✗ Tidak ditemukan: Mata Air Tonda
# ✗ Tidak ditemukan: Gunung Tondano
# ✗ Tidak ditemukan: Goa Ria
# ✓ Ditemukan: Taman Kota Palu
# ✓ Ditemukan: Museum Palu
# ✗ Tidak ditemukan: Museum Luwuk
# ✗ Tidak ditemukan: Mall Tatura
# ✓ Ditemukan: Palu Grand Mall
# ✗ Tidak ditemukan: Mall Mega Palu
# ✗ Tidak ditemukan: Mall Luwuk
# ✗ Tidak ditemukan: Mega Mall Ternate
# ✓ Ditemukan: Plaza Palu
# ...

# %%
from geopy.geocoders import Nominatim
import pandas as pd
import time

# Daftar wisata Sulawesi Selatan
wisata_sulsel_list = [
    "Pantai Losari", "Pantai Bira", "Pantai Tanjung Bira", "Taman Nasional Bantimurung",
    "Taman Nasional Wakatobi", "Air Terjun Takapala", "Air Terjun Malino", "Gunung Bawakaraeng",
    "Gunung Lompobattang", "Museum La Galigo", "Museum Kota Makassar", "Masjid Raya Makassar",
    "Monumen Mandala", "Benteng Rotterdam", "Fort Somba Opu", "Kampung Adat Toraja", "Kampung Adat Bugis",
    "Pulau Samalona", "Pulau Kodingareng", "Pulau Tidung", "Pulau Kapoposang", "Kepulauan Spermonde",
    "Pasar Sentral Makassar", "Pasar Malam Makassar", "Pasar Turi Makassar", "Mall Ratu Indah",
    "Trans Studio Mall", "Mall Panakukkang", "Mall GTC Makassar", "Grand Mall Makassar",
    "Mall Lippo Plaza", "Mall Daya Makassar", "Mall Tanjung Bunga", "La'boq Coffee", "Puppeteer Makassar",
    "Kebun Raya Makassar", "Kebun Raya Malino", "Taman Wisata Alam Rammang Rammang", "Taman Wisata Alam Pangkep",
    "Taman Wisata Alam Malino", "Wahana Keluarga Makassar", "Wahana Keluarga Trans Studio",
    "Wahana Wisata Alam Makassar", "Taman Kupu-kupu Toraja", "Kampung Wisata Buginese", "Taman Kota Makassar",
    "Kampung Wisata Toraja", "Rumah Adat Toraja", "Rumah Adat Bugis", "Masjid Al-Markaz", "Pantai Tanjung Karang",
    "Pantai Takisung", "Pantai Tanjung Alang", "Gunung Latimojong", "Gunung Nona", "Taman Nasional Tamalaulau",
    "Alun-Alun Makassar", "Candi Batu Pake", "Goa Londa", "Goa Sarong", "Goa Lappangan", "Goa Patu"
]

# Inisialisasi geolocator
geolocator = Nominatim(user_agent="wisata_geocoder_sulsel")
results = []

# Proses geocoding
for nama in wisata_sulsel_list:
    try:
        query = f"{nama}, Sulawesi Selatan, Indonesia"
        location = geolocator.geocode(query, exactly_one=True, addressdetails=True)
        if location:
            addr = location.raw.get('address', {})
            results.append({
                "nama_wisata": nama,
                "latitude": location.latitude,
                "longitude": location.longitude,
                "alamat": location.address,
                "provinsi": addr.get('state', ''),
                "kota_kabupaten": addr.get('city', '') or addr.get('county', '') or addr.get('region', '')
            })
            print(f"✓ Ditemukan: {nama}")
        else:
            results.append({
                "nama_wisata": nama,
                "latitude": None,
                "longitude": None,
                "alamat": "Not Found",
                "provinsi": "",
                "kota_kabupaten": ""
            })
            print(f"✗ Tidak ditemukan: {nama}")
    except Exception as e:
        results.append({
            "nama_wisata": nama,
            "latitude": None,
            "longitude": None,
            "alamat": f"Error: {e}",
            "provinsi": "",
            "kota_kabupaten": ""
        })
        print(f"⚠️ Error: {nama} - {e}")
    time.sleep(1)

# Simpan ke CSV
df = pd.DataFrame(results)
df.to_csv("wisata_sulsel_with_mall.csv", index=False)
print("✅ Data wisata Sulawesi Selatan berhasil disimpan ke 'wisata_sulsel_with_mall.csv'")
# Out:
# ✓ Ditemukan: Pantai Losari
# ✓ Ditemukan: Pantai Bira
# ✗ Tidak ditemukan: Pantai Tanjung Bira
# ✓ Ditemukan: Taman Nasional Bantimurung
# ✗ Tidak ditemukan: Taman Nasional Wakatobi
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=Air+Terjun+Takapala%2C+Sulawesi+Selatan%2C+Indonesia&format=json&limit=1&addressdetails=1
# ✗ Tidak ditemukan: Air Terjun Takapala
# ✗ Tidak ditemukan: Air Terjun Malino
# ✓ Ditemukan: Gunung Bawakaraeng
# ✓ Ditemukan: Gunung Lompobattang
# ✓ Ditemukan: Museum La Galigo
# ✓ Ditemukan: Museum Kota Makassar
# ✓ Ditemukan: Masjid Raya Makassar
# ✓ Ditemukan: Monumen Mandala
# ✗ Tidak ditemukan: Benteng Rotterdam
# ✗ Tidak ditemukan: Fort Somba Opu
# ✗ Tidak ditemukan: Kampung Adat Toraja
# ✗ Tidak ditemukan: Kampung Adat Bugis
# ...

# %%
from geopy.geocoders import Nominatim
import pandas as pd
import time

# Daftar wisata Sulawesi Tenggara
wisata_sultra_list = [
    "Taman Nasional Wakatobi", "Pantai Balu-Balu", "Pantai Mone", "Pantai Nambo",
    "Pantai Kampung Baru", "Gunung Rontu", "Air Terjun Moramo", "Air Terjun Mata Air Tiga",
    "Kampung Adat Tolaki", "Kampung Adat Buton", "Pantai Lasusua", "Pulau Binongko",
    "Pantai Tanjung Taipa", "Goa Jepang Kendari", "Goa Pintu Langit", "Taman Nasional Kendari",
    "Taman Nasional Sulaweki", "Pantai Saronde", "Pulau Labengki", "Gunung Muna",
    "Kebun Raya Kendari", "Pusat Perbelanjaan Mega Mall Kendari", "Kendari Town Square",
    "Sulawesi Tenggara Mall", "Kendari Plaza", "Mall Centro Kendari", "Transmart Kendari",
    "Lagoa Beach Resort", "Alun-Alun Kendari", "Taman Wisata Alam Air Terjun Moramo", "Taman Kupu-kupu Moramo",
    "Kampung Wisata Siontapina", "Pantai Sampara", "Pantai Bente", "Pantai Sawa", "Pasar Rakyat Kendari",
    "Museum Sulawesi Tenggara", "Monumen Merah Putih Kendari", "Pasar Sentral Kendari", "Pasar Malam Kendari",
    "Taman Kota Kendari", "Kampung Wisata Kendari", "Taman Kota Wakatobi", "Pasar Wakatobi",
    "Pantai Baubau", "Pantai Mandonga", "Pantai Kulisusu", "Taman Nasional Buton", "Gunung Nipa",
    "Pantai Wakatobi", "Taman Wisata Alam Kamaru", "Wahana Wisata Alam Wakatobi", "Pantai Moramo",
    "Kampung Sumber", "Kampung Bemban", "Kampung Sintri"
]

# Inisialisasi geolocator
geolocator = Nominatim(user_agent="wisata_geocoder_sultra")
results = []

# Proses geocoding
for nama in wisata_sultra_list:
    try:
        query = f"{nama}, Sulawesi Tenggara, Indonesia"
        location = geolocator.geocode(query, exactly_one=True, addressdetails=True)
        if location:
            addr = location.raw.get('address', {})
            results.append({
                "nama_wisata": nama,
                "latitude": location.latitude,
                "longitude": location.longitude,
                "alamat": location.address,
                "provinsi": addr.get('state', ''),
                "kota_kabupaten": addr.get('city', '') or addr.get('county', '') or addr.get('region', '')
            })
            print(f"✓ Ditemukan: {nama}")
        else:
            results.append({
                "nama_wisata": nama,
                "latitude": None,
                "longitude": None,
                "alamat": "Not Found",
                "provinsi": "",
                "kota_kabupaten": ""
            })
            print(f"✗ Tidak ditemukan: {nama}")
    except Exception as e:
        results.append({
            "nama_wisata": nama,
            "latitude": None,
            "longitude": None,
            "alamat": f"Error: {e}",
            "provinsi": "",
            "kota_kabupaten": ""
        })
        print(f"⚠️ Error: {nama} - {e}")
    time.sleep(1)

# Simpan ke CSV
df = pd.DataFrame(results)
df.to_csv("wisata_sultra_with_mall.csv", index=False)
print("✅ Data wisata Sulawesi Tenggara berhasil disimpan ke 'wisata_sultra_with_mall.csv'")
# Out:
# ✓ Ditemukan: Taman Nasional Wakatobi
# ✗ Tidak ditemukan: Pantai Balu-Balu
# ✗ Tidak ditemukan: Pantai Mone
# ✓ Ditemukan: Pantai Nambo
# ✗ Tidak ditemukan: Pantai Kampung Baru
# ✗ Tidak ditemukan: Gunung Rontu
# ✓ Ditemukan: Air Terjun Moramo
# ✗ Tidak ditemukan: Air Terjun Mata Air Tiga
# ✗ Tidak ditemukan: Kampung Adat Tolaki
# ✗ Tidak ditemukan: Kampung Adat Buton
# ✗ Tidak ditemukan: Pantai Lasusua
# ✓ Ditemukan: Pulau Binongko
# ✗ Tidak ditemukan: Pantai Tanjung Taipa
# ✗ Tidak ditemukan: Goa Jepang Kendari
# ✗ Tidak ditemukan: Goa Pintu Langit
# ✗ Tidak ditemukan: Taman Nasional Kendari
# ✗ Tidak ditemukan: Taman Nasional Sulaweki
# ✗ Tidak ditemukan: Pantai Saronde
# ✗ Tidak ditemukan: Pulau Labengki
# ✗ Tidak ditemukan: Gunung Muna
# ✗ Tidak ditemukan: Kebun Raya Kendari
# ✗ Tidak ditemukan: Pusat Perbelanjaan Mega Mall Kendari
# ✓ Ditemukan: Kendari Town Square
# ✗ Tidak ditemukan: Sulawesi Tenggara Mall
# ✓ Ditemukan: Kendari Plaza
# ✗ Tidak ditemukan: Mall Centro Kendari
# ...

# %%
from geopy.geocoders import Nominatim
import pandas as pd
import time

# Daftar wisata Sulawesi Barat
wisata_sulbar_list = [
    "Pantai Takandeang", "Pantai Tanjung Datu", "Pantai Palippis", "Taman Nasional Lore Lindu",
    "Gunung Saddang", "Gunung Baluran", "Air Terjun Enrekang", "Air Terjun Soppeng",
    "Air Terjun Tamasapi", "Goa Mamboro", "Kampung Adat Mamuju", "Taman Nasional Maros",
    "Kampung Wisata Baraka", "Kampung Wisata Sumber", "Goa Batu Sapi", "Monumen Mamuju",
    "Pantai Mamuju", "Pantai Tanjung Karang", "Pantai Tanjung Bunga", "Kampung Wisata Mamuju",
    "Pasar Mamuju", "Pasar Malam Mamuju", "Taman Kota Mamuju", "Museum Sulawesi Barat",
    "Monumen Nasional Mamuju", "Kebun Raya Mamuju", "Mall Mamuju", "Transmart Mamuju",
    "Mall Ratu Mamuju", "Mamuju Grand Mall", "Sampodja Palace", "Pasar Tradisional Mamuju",
    "Pasar Modern Mamuju", "Pantai Ampan", "Pantai Bulu" , "Pantai Lata-Lata", "Pantai Kuri",
    "Taman Wisata Alam", "Kampung Wisata Mamuju Utara", "Alun-Alun Mamuju", "Kebun Teh Mamuju",
    "Bukit Mamuju", "Kampung Wisata Mamuju Selatan", "Goa Tondong", "Taman Nasional Poso"
]

# Inisialisasi geolocator
geolocator = Nominatim(user_agent="wisata_geocoder_sulbar")
results = []

# Proses geocoding
for nama in wisata_sulbar_list:
    try:
        query = f"{nama}, Sulawesi Barat, Indonesia"
        location = geolocator.geocode(query, exactly_one=True, addressdetails=True)
        if location:
            addr = location.raw.get('address', {})
            results.append({
                "nama_wisata": nama,
                "latitude": location.latitude,
                "longitude": location.longitude,
                "alamat": location.address,
                "provinsi": addr.get('state', ''),
                "kota_kabupaten": addr.get('city', '') or addr.get('county', '') or addr.get('region', '')
            })
            print(f"✓ Ditemukan: {nama}")
        else:
            results.append({
                "nama_wisata": nama,
                "latitude": None,
                "longitude": None,
                "alamat": "Not Found",
                "provinsi": "",
                "kota_kabupaten": ""
            })
            print(f"✗ Tidak ditemukan: {nama}")
    except Exception as e:
        results.append({
            "nama_wisata": nama,
            "latitude": None,
            "longitude": None,
            "alamat": f"Error: {e}",
            "provinsi": "",
            "kota_kabupaten": ""
        })
        print(f"⚠️ Error: {nama} - {e}")
    time.sleep(1)

# Simpan ke CSV
df = pd.DataFrame(results)
df.to_csv("wisata_sulbar_with_mall.csv", index=False)
print("✅ Data wisata Sulawesi Barat berhasil disimpan ke 'wisata_sulbar_with_mall.csv'")
# Out:
# ✗ Tidak ditemukan: Pantai Takandeang
# ✗ Tidak ditemukan: Pantai Tanjung Datu
# ✓ Ditemukan: Pantai Palippis
# ✗ Tidak ditemukan: Taman Nasional Lore Lindu
# ✗ Tidak ditemukan: Gunung Saddang
# ✗ Tidak ditemukan: Gunung Baluran
# ✗ Tidak ditemukan: Air Terjun Enrekang
# ✗ Tidak ditemukan: Air Terjun Soppeng
# ✗ Tidak ditemukan: Air Terjun Tamasapi
# ✗ Tidak ditemukan: Goa Mamboro
# ✗ Tidak ditemukan: Kampung Adat Mamuju
# ✗ Tidak ditemukan: Taman Nasional Maros
# ✗ Tidak ditemukan: Kampung Wisata Baraka
# ✗ Tidak ditemukan: Kampung Wisata Sumber
# ✗ Tidak ditemukan: Goa Batu Sapi
# ✗ Tidak ditemukan: Monumen Mamuju
# ✓ Ditemukan: Pantai Mamuju
# ✗ Tidak ditemukan: Pantai Tanjung Karang
# ✗ Tidak ditemukan: Pantai Tanjung Bunga
# ✗ Tidak ditemukan: Kampung Wisata Mamuju
# ✓ Ditemukan: Pasar Mamuju
# ✗ Tidak ditemukan: Pasar Malam Mamuju
# ✗ Tidak ditemukan: Taman Kota Mamuju
# ✓ Ditemukan: Museum Sulawesi Barat
# ✗ Tidak ditemukan: Monumen Nasional Mamuju
# ...

# %%
from geopy.geocoders import Nominatim
import pandas as pd
import time

# Daftar wisata Maluku
wisata_maluku_list = [
    "Pantai Natsepa", "Pantai Ora", "Pulau Ambon", "Pulau Saparua", "Pulau Buru", "Pulau Ternate",
    "Gunung Api Ternate", "Air Terjun Waiyame", "Air Terjun Hatuela", "Taman Laut Banda",
    "Goa Lawa", "Goa Batu", "Pulau Banda Neira", "Benteng Oranje", "Taman Nasional Manusela",
    "Kampung Adat Maluku", "Masjid Raya Al-Fatah Ambon", "Monumen Pattimura", "Museum Siwalima",
    "Pasar Ambon", "Pasar Ikan Ambon", "Pantai Hunimua", "Pantai Pasir Putih", "Pantai Laha",
    "Kepulauan Kei", "Pulau Kei Kecil", "Pantai Sumber Sari", "Taman Laut Banda Neira",
    "Bukit Rumatiga", "Pantai Waisale", "Kampung Wisata Saparua", "Pulau Buru", "Pulau Pulau Maluku",
    "Pantai Poka", "Pantai Tiga", "Pantai Lobo", "Pasar Tradisional Ambon", "Mall Ambon",
    "Maluku Mall", "Transmart Ambon", "Dolan Mall", "Taman Wisata Alam Hualoy", "Taman Wisata Teluk Ambon",
    "Alun-Alun Ambon", "Taman Kota Ambon", "Pantai Waiyame", "Pantai Waisale", "Gunung Maru",
    "Gunung Saniri", "Taman Nasional Gunung Manusela", "Pantai Labo", "Kampung Adat Kei"
]

# Inisialisasi geolocator
geolocator = Nominatim(user_agent="wisata_geocoder_maluku")
results = []

# Proses geocoding
for nama in wisata_maluku_list:
    try:
        query = f"{nama}, Maluku, Indonesia"
        location = geolocator.geocode(query, exactly_one=True, addressdetails=True)
        if location:
            addr = location.raw.get('address', {})
            results.append({
                "nama_wisata": nama,
                "latitude": location.latitude,
                "longitude": location.longitude,
                "alamat": location.address,
                "provinsi": addr.get('state', ''),
                "kota_kabupaten": addr.get('city', '') or addr.get('county', '') or addr.get('region', '')
            })
            print(f"✓ Ditemukan: {nama}")
        else:
            results.append({
                "nama_wisata": nama,
                "latitude": None,
                "longitude": None,
                "alamat": "Not Found",
                "provinsi": "",
                "kota_kabupaten": ""
            })
            print(f"✗ Tidak ditemukan: {nama}")
    except Exception as e:
        results.append({
            "nama_wisata": nama,
            "latitude": None,
            "longitude": None,
            "alamat": f"Error: {e}",
            "provinsi": "",
            "kota_kabupaten": ""
        })
        print(f"⚠️ Error: {nama} - {e}")
    time.sleep(1)

# Simpan ke CSV
df = pd.DataFrame(results)
df.to_csv("wisata_maluku_with_mall.csv", index=False)
print("✅ Data wisata Maluku berhasil disimpan ke 'wisata_maluku_with_mall.csv'")
# Out:
# ✓ Ditemukan: Pantai Natsepa
# ✗ Tidak ditemukan: Pantai Ora
# ✓ Ditemukan: Pulau Ambon
# ✓ Ditemukan: Pulau Saparua
# ✓ Ditemukan: Pulau Buru
# ✓ Ditemukan: Pulau Ternate
# ✗ Tidak ditemukan: Gunung Api Ternate
# ✗ Tidak ditemukan: Air Terjun Waiyame
# ✗ Tidak ditemukan: Air Terjun Hatuela
# ✓ Ditemukan: Taman Laut Banda
# ✗ Tidak ditemukan: Goa Lawa
# ✗ Tidak ditemukan: Goa Batu
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=Pulau+Banda+Neira%2C+Maluku%2C+Indonesia&format=json&limit=1&addressdetails=1
# ✗ Tidak ditemukan: Pulau Banda Neira
# ✗ Tidak ditemukan: Benteng Oranje
# ✓ Ditemukan: Taman Nasional Manusela
# ✗ Tidak ditemukan: Kampung Adat Maluku
# ✗ Tidak ditemukan: Masjid Raya Al-Fatah Ambon
# ✓ Ditemukan: Monumen Pattimura
# ...

# %%
from geopy.geocoders import Nominatim
import pandas as pd
import time

# Daftar wisata Maluku Utara
wisata_malut_list = [
    "Pulau Morotai", "Pantai Gorua", "Pantai Sulamadaha", "Gunung Gamalama", "Pantai Ternate",
    "Pantai Bobong", "Pulau Maitara", "Pulau Tidore", "Taman Nasional Morotai", "Pantai Hiri",
    "Pantai Dodinga", "Pulau Bacan", "Pulau Mandioli", "Pantai Tobelo", "Air Terjun Waibesi",
    "Pantai Pelabuhan Rakyat", "Pantai Kao", "Taman Laut Ternate", "Kampung Adat Tidore", "Pulau Halmahera",
    "Pantai Rum", "Monumen Tidore", "Museum Maluku Utara", "Pasar Tradisional Ternate", "Pasar Ikan Tidore",
    "Mall Ternate", "Transmart Ternate", "Mega Mall Ternate", "Pantai Lae-lae", "Kampung Wisata Ternate",
    "Taman Wisata Alam", "Pantai Tepian Laut", "Kampung Sahu", "Bukit Nusa", "Pantai Labuha", "Taman Laut Gosale",
    "Gunung Ternate", "Taman Nasional Halmahera", "Pantai Geda", "Kampung Wisata Sulamadaha", "Kampung Wisata Bastiong"
]

# Inisialisasi geolocator
geolocator = Nominatim(user_agent="wisata_geocoder_malut")
results = []

# Proses geocoding
for nama in wisata_malut_list:
    try:
        query = f"{nama}, Maluku Utara, Indonesia"
        location = geolocator.geocode(query, exactly_one=True, addressdetails=True)
        if location:
            addr = location.raw.get('address', {})
            results.append({
                "nama_wisata": nama,
                "latitude": location.latitude,
                "longitude": location.longitude,
                "alamat": location.address,
                "provinsi": addr.get('state', ''),
                "kota_kabupaten": addr.get('city', '') or addr.get('county', '') or addr.get('region', '')
            })
            print(f"✓ Ditemukan: {nama}")
        else:
            results.append({
                "nama_wisata": nama,
                "latitude": None,
                "longitude": None,
                "alamat": "Not Found",
                "provinsi": "",
                "kota_kabupaten": ""
            })
            print(f"✗ Tidak ditemukan: {nama}")
    except Exception as e:
        results.append({
            "nama_wisata": nama,
            "latitude": None,
            "longitude": None,
            "alamat": f"Error: {e}",
            "provinsi": "",
            "kota_kabupaten": ""
        })
        print(f"⚠️ Error: {nama} - {e}")
    time.sleep(1)

# Simpan ke CSV
df = pd.DataFrame(results)
df.to_csv("wisata_malut_with_mall.csv", index=False)
print("✅ Data wisata Maluku Utara berhasil disimpan ke 'wisata_malut_with_mall.csv'")
# Out:
# ✓ Ditemukan: Pulau Morotai
# ✗ Tidak ditemukan: Pantai Gorua
# ✓ Ditemukan: Pantai Sulamadaha
# ✓ Ditemukan: Gunung Gamalama
# ✓ Ditemukan: Pantai Ternate
# ✗ Tidak ditemukan: Pantai Bobong
# ✓ Ditemukan: Pulau Maitara
# ✓ Ditemukan: Pulau Tidore
# ✗ Tidak ditemukan: Taman Nasional Morotai
# ✗ Tidak ditemukan: Pantai Hiri
# ✗ Tidak ditemukan: Pantai Dodinga
# ✓ Ditemukan: Pulau Bacan
# ✓ Ditemukan: Pulau Mandioli
# ✗ Tidak ditemukan: Pantai Tobelo
# ✗ Tidak ditemukan: Air Terjun Waibesi
# ✗ Tidak ditemukan: Pantai Pelabuhan Rakyat
# ✗ Tidak ditemukan: Pantai Kao
# ✗ Tidak ditemukan: Taman Laut Ternate
# ✗ Tidak ditemukan: Kampung Adat Tidore
# ✓ Ditemukan: Pulau Halmahera
# ✗ Tidak ditemukan: Pantai Rum
# ✗ Tidak ditemukan: Monumen Tidore
# ✓ Ditemukan: Museum Maluku Utara
# ✗ Tidak ditemukan: Pasar Tradisional Ternate
# ✗ Tidak ditemukan: Pasar Ikan Tidore
# ✓ Ditemukan: Mall Ternate
# ✗ Tidak ditemukan: Transmart Ternate
# ✗ Tidak ditemukan: Mega Mall Ternate
# ...

# %%
from geopy.geocoders import Nominatim
import pandas as pd
import time

# Daftar wisata Papua Barat
wisata_papua_barat_list = [
    "Raja Ampat", "Pantai Waisai", "Pulau Misool", "Pulau Wayag", "Kepulauan Raja Ampat", "Goa Kelelawar",
    "Taman Nasional Arfak", "Gunung Arfak", "Pulau Batanta", "Pantai Pianemo", "Pantai Sawinggrai",
    "Taman Laut Raja Ampat", "Pulau Waigeo", "Pulau Kri", "Pulau Gam", "Air Terjun Batanta", "Taman Nasional Wasur",
    "Pantai Teluk Cendrawasih", "Pantai Maruni", "Pantai Asmat", "Museum Manokwari", "Monumen Sorong",
    "Alun-Alun Manokwari", "Pantai Sebesi", "Pantai Tanjung Sialang", "Kampung Adat Papua Barat", "Air Terjun Amban",
    "Kampung Wisata Raja Ampat", "Situs Batu Tiga", "Situs Kerajaan Papua", "Pantai Lubuk", "Pantai Lorentz",
    "Kampung Laut Cendrawasih", "Pantai Kaimana", "Pantai Maumeri", "Gunung Misool", "Pulau Mioswaar", "Pulau Mioskor",
    "Pantai Kurudu", "Pantai Aru", "Bukit Arfak", "Goa Cendrawasih", "Taman Wisata Alam Wasur", "Pantai Perbatasan",
    "Kampung Alam Raja Ampat", "Bukit Cendrawasih", "Pantai Marai", "Taman Nasional Lorentz"
]

# Inisialisasi geolocator
geolocator = Nominatim(user_agent="wisata_geocoder_papua_barat")
results = []

# Proses geocoding
for nama in wisata_papua_barat_list:
    try:
        query = f"{nama}, Papua Barat, Indonesia"
        location = geolocator.geocode(query, exactly_one=True, addressdetails=True)
        if location:
            addr = location.raw.get('address', {})
            results.append({
                "nama_wisata": nama,
                "latitude": location.latitude,
                "longitude": location.longitude,
                "alamat": location.address,
                "provinsi": addr.get('state', ''),
                "kota_kabupaten": addr.get('city', '') or addr.get('county', '') or addr.get('region', '')
            })
            print(f"✓ Ditemukan: {nama}")
        else:
            results.append({
                "nama_wisata": nama,
                "latitude": None,
                "longitude": None,
                "alamat": "Not Found",
                "provinsi": "",
                "kota_kabupaten": ""
            })
            print(f"✗ Tidak ditemukan: {nama}")
    except Exception as e:
        results.append({
            "nama_wisata": nama,
            "latitude": None,
            "longitude": None,
            "alamat": f"Error: {e}",
            "provinsi": "",
            "kota_kabupaten": ""
        })
        print(f"⚠️ Error: {nama} - {e}")
    time.sleep(1)

# Simpan ke CSV
df = pd.DataFrame(results)
df.to_csv("wisata_papua_barat_with_mall.csv", index=False)
print("✅ Data wisata Papua Barat berhasil disimpan ke 'wisata_papua_barat_with_mall.csv'")
# Out:
# ✓ Ditemukan: Raja Ampat
# ✓ Ditemukan: Pantai Waisai
# ✓ Ditemukan: Pulau Misool
# ✓ Ditemukan: Pulau Wayag
# ✓ Ditemukan: Kepulauan Raja Ampat
# ✗ Tidak ditemukan: Goa Kelelawar
# ✗ Tidak ditemukan: Taman Nasional Arfak
# ✓ Ditemukan: Gunung Arfak
# ✓ Ditemukan: Pulau Batanta
# ✗ Tidak ditemukan: Pantai Pianemo
# ✗ Tidak ditemukan: Pantai Sawinggrai
# ✗ Tidak ditemukan: Taman Laut Raja Ampat
# ✓ Ditemukan: Pulau Waigeo
# ✓ Ditemukan: Pulau Kri
# ✓ Ditemukan: Pulau Gam
# ✗ Tidak ditemukan: Air Terjun Batanta
# ✗ Tidak ditemukan: Taman Nasional Wasur
# ✗ Tidak ditemukan: Pantai Teluk Cendrawasih
# ✗ Tidak ditemukan: Pantai Maruni
# ✗ Tidak ditemukan: Pantai Asmat
# ✗ Tidak ditemukan: Museum Manokwari
# ✗ Tidak ditemukan: Monumen Sorong
# ✗ Tidak ditemukan: Alun-Alun Manokwari
# ✗ Tidak ditemukan: Pantai Sebesi
# ✗ Tidak ditemukan: Pantai Tanjung Sialang
# ✗ Tidak ditemukan: Kampung Adat Papua Barat
# ✗ Tidak ditemukan: Air Terjun Amban
# ✗ Tidak ditemukan: Kampung Wisata Raja Ampat
# ...

# %%
from geopy.geocoders import Nominatim
import pandas as pd
import time

# Daftar wisata Papua Selatan
wisata_papua_selatan_list = [
    "Pantai Nabire", "Pantai Bintuni", "Taman Nasional Wasur", "Pulau Numfor", "Gunung Meratus",
    "Pantai Mamberamo", "Kampung Adat Papua Selatan", "Danau Sentani", "Air Terjun Wamena",
    "Pantai Aitape", "Taman Laut Cendrawasih", "Gunung Trikora", "Pantai Maratua", "Pulau Biak",
    "Pantai Waisai", "Pantai Bintuni", "Gunung Bukit Barisan", "Pantai Arso", "Monumen Pepera",
    "Taman Laut Raja Ampat", "Air Terjun Mamberamo", "Kampung Wisata Bintuni", "Pantai Bulu",
    "Air Terjun Sosiri", "Pantai Abar", "Museum Kota Sorong", "Pantai Rumeron", "Pantai Mambaramo",
    "Pantai Tanjung", "Sungai Mandobo", "Gunung Puncak Jaya", "Pantai Wamena", "Bukit Cendrawasih",
    "Pantai Tolikara", "Taman Laut Berau", "Pulau Asmat", "Pulau Yapen", "Taman Nasional Teluk Cenderawasih"
]

# Inisialisasi geolocator
geolocator = Nominatim(user_agent="wisata_geocoder_papua_selatan")
results = []

# Proses geocoding
for nama in wisata_papua_selatan_list:
    try:
        query = f"{nama}, Papua Selatan, Indonesia"
        location = geolocator.geocode(query, exactly_one=True, addressdetails=True)
        if location:
            addr = location.raw.get('address', {})
            results.append({
                "nama_wisata": nama,
                "latitude": location.latitude,
                "longitude": location.longitude,
                "alamat": location.address,
                "provinsi": addr.get('state', ''),
                "kota_kabupaten": addr.get('city', '') or addr.get('county', '') or addr.get('region', '')
            })
            print(f"✓ Ditemukan: {nama}")
        else:
            results.append({
                "nama_wisata": nama,
                "latitude": None,
                "longitude": None,
                "alamat": "Not Found",
                "provinsi": "",
                "kota_kabupaten": ""
            })
            print(f"✗ Tidak ditemukan: {nama}")
    except Exception as e:
        results.append({
            "nama_wisata": nama,
            "latitude": None,
            "longitude": None,
            "alamat": f"Error: {e}",
            "provinsi": "",
            "kota_kabupaten": ""
        })
        print(f"⚠️ Error: {nama} - {e}")
    time.sleep(1)

# Simpan ke CSV
df = pd.DataFrame(results)
df.to_csv("wisata_papua_selatan_with_mall.csv", index=False)
print("✅ Data wisata Papua Selatan berhasil disimpan ke 'wisata_papua_selatan_with_mall.csv'")
# Out:
# ✗ Tidak ditemukan: Pantai Nabire
# ✗ Tidak ditemukan: Pantai Bintuni
# ✓ Ditemukan: Taman Nasional Wasur
# ✗ Tidak ditemukan: Pulau Numfor
# ✗ Tidak ditemukan: Gunung Meratus
# ✗ Tidak ditemukan: Pantai Mamberamo
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=Kampung+Adat+Papua+Selatan%2C+Papua+Selatan%2C+Indonesia&format=json&limit=1&addressdetails=1
# ✗ Tidak ditemukan: Kampung Adat Papua Selatan
# ✗ Tidak ditemukan: Danau Sentani
# ✗ Tidak ditemukan: Air Terjun Wamena
# ✗ Tidak ditemukan: Pantai Aitape
# ✗ Tidak ditemukan: Taman Laut Cendrawasih
# ✗ Tidak ditemukan: Gunung Trikora
# ✗ Tidak ditemukan: Pantai Maratua
# ✗ Tidak ditemukan: Pulau Biak
# ✗ Tidak ditemukan: Pantai Waisai
# ✗ Tidak ditemukan: Pantai Bintuni
# ✗ Tidak ditemukan: Gunung Bukit Barisan
# ...

# %%
from geopy.geocoders import Nominatim
import pandas as pd
import time

# Daftar wisata Papua Tengah
wisata_papua_tengah_list = [
    "Pantai Paniai", "Pantai Yosim", "Gunung Cyclops", "Danau Sentani", "Pantai Wamena", "Pantai Marau",
    "Taman Nasional Cyclops", "Pantai Longgo", "Gunung Gunung Bintang", "Pantai Lano", "Air Terjun Kapiran",
    "Pantai Ombak Laut", "Pantai Katros", "Pulau Raja Ampat", "Taman Laut Pulau Mamberamo", "Air Terjun Raja Ampat",
    "Air Terjun Wambena", "Bukit Mokmer", "Pantai Doreri", "Pantai Kisaran", "Kampung Wisata Wamena",
    "Taman Nasional Teluk Cenderawasih", "Pantai Ambon", "Gunung Puncak Jaya", "Pantai Teluk Cendrawasih",
    "Pantai Jayapura", "Taman Wisata Alam Wasur", "Kampung Wamena", "Taman Laut Raja Ampat", "Pantai Akat",
    "Air Terjun Kopai", "Gunung Lorentz", "Pantai Pantai Ternate", "Pantai Sikumana", "Taman Laut Raja Ampat",
    "Pantai Waigeo", "Pantai Maruni", "Pantai Anambas", "Gunung Tambrauw", "Gunung Sombap", "Pantai Lolo",
    "Pantai Mamberamo", "Pantai Longgo", "Gunung Marum", "Gunung Rimba Papua", "Pantai Lae-lae", "Pantai Siallagan",
    "Pantai Amba", "Air Terjun Alam Indah", "Kampung Adat Puncak Jaya"
]

# Inisialisasi geolocator
geolocator = Nominatim(user_agent="wisata_geocoder_papua_tengah")
results = []

# Proses geocoding
for nama in wisata_papua_tengah_list:
    try:
        query = f"{nama}, Papua Tengah, Indonesia"
        location = geolocator.geocode(query, exactly_one=True, addressdetails=True)
        if location:
            addr = location.raw.get('address', {})
            results.append({
                "nama_wisata": nama,
                "latitude": location.latitude,
                "longitude": location.longitude,
                "alamat": location.address,
                "provinsi": addr.get('state', ''),
                "kota_kabupaten": addr.get('city', '') or addr.get('county', '') or addr.get('region', '')
            })
            print(f"✓ Ditemukan: {nama}")
        else:
            results.append({
                "nama_wisata": nama,
                "latitude": None,
                "longitude": None,
                "alamat": "Not Found",
                "provinsi": "",
                "kota_kabupaten": ""
            })
            print(f"✗ Tidak ditemukan: {nama}")
    except Exception as e:
        results.append({
            "nama_wisata": nama,
            "latitude": None,
            "longitude": None,
            "alamat": f"Error: {e}",
            "provinsi": "",
            "kota_kabupaten": ""
        })
        print(f"⚠️ Error: {nama} - {e}")
    time.sleep(1)

# Simpan ke CSV
df = pd.DataFrame(results)
df.to_csv("wisata_papua_tengah_with_mall.csv", index=False)
print("✅ Data wisata Papua Tengah berhasil disimpan ke 'wisata_papua_tengah_with_mall.csv'")
# Out:
# ✗ Tidak ditemukan: Pantai Paniai
# ✗ Tidak ditemukan: Pantai Yosim
# ✗ Tidak ditemukan: Gunung Cyclops
# ✗ Tidak ditemukan: Danau Sentani
# ✗ Tidak ditemukan: Pantai Wamena
# ✗ Tidak ditemukan: Pantai Marau
# ✗ Tidak ditemukan: Taman Nasional Cyclops
# ✗ Tidak ditemukan: Pantai Longgo
# ✗ Tidak ditemukan: Gunung Gunung Bintang
# ✗ Tidak ditemukan: Pantai Lano
# ✗ Tidak ditemukan: Air Terjun Kapiran
# ✗ Tidak ditemukan: Pantai Ombak Laut
# ✗ Tidak ditemukan: Pantai Katros
# ✗ Tidak ditemukan: Pulau Raja Ampat
# ✗ Tidak ditemukan: Taman Laut Pulau Mamberamo
# ✗ Tidak ditemukan: Air Terjun Raja Ampat
# ✗ Tidak ditemukan: Air Terjun Wambena
# ✗ Tidak ditemukan: Bukit Mokmer
# ✗ Tidak ditemukan: Pantai Doreri
# ✗ Tidak ditemukan: Pantai Kisaran
# ✗ Tidak ditemukan: Kampung Wisata Wamena
# ✓ Ditemukan: Taman Nasional Teluk Cenderawasih
# ✗ Tidak ditemukan: Pantai Ambon
# ✓ Ditemukan: Gunung Puncak Jaya
# ✗ Tidak ditemukan: Pantai Teluk Cendrawasih
# ✗ Tidak ditemukan: Pantai Jayapura
# ...

# %%
from geopy.geocoders import Nominatim
import pandas as pd
import time

# Daftar wisata Papua Pegunungan
wisata_papua_pegunungan_list = [
    "Danau Tiga Ribu", "Gunung Carstensz", "Air Terjun Wamena", "Gunung Trikora", "Pantai Laut Mamberamo",
    "Taman Nasional Wasur", "Gunung Puncak Jaya", "Kampung Adat Papua Pegunungan", "Pantai Teluk Cendrawasih",
    "Pantai Wamena", "Pantai Jayapura", "Air Terjun Sosiri", "Pantai Tanjung", "Pantai Rumeron",
    "Pantai Abar", "Pantai Waisai", "Pantai Lano", "Pantai Maruni", "Gunung Cyclops", "Gunung Lorentz",
    "Taman Laut Raja Ampat", "Pulau Raja Ampat", "Pantai Maratua", "Pantai Ombak Laut", "Kampung Wisata Wamena",
    "Air Terjun Batanta", "Air Terjun Sosiri", "Pantai Arfak", "Pantai Gam", "Pantai Asmat", "Pantai Sumbawa",
    "Pantai Pantai Ternate", "Sungai Mandobo", "Gunung Misool", "Pantai Longgo", "Pantai Ternate",
    "Kampung Tradisional Yei", "Kampung Wamena", "Gunung Tambrauw", "Gunung Trikora", "Air Terjun Kopai",
    "Pantai Biak", "Pantai Perbatasan", "Taman Laut Raja Ampat", "Air Terjun Lorentz", "Taman Laut Cenderawasih"
]

# Inisialisasi geolocator
geolocator = Nominatim(user_agent="wisata_geocoder_papua_pegunungan")
results = []

# Proses geocoding
for nama in wisata_papua_pegunungan_list:
    try:
        query = f"{nama}, Papua Pegunungan, Indonesia"
        location = geolocator.geocode(query, exactly_one=True, addressdetails=True)
        if location:
            addr = location.raw.get('address', {})
            results.append({
                "nama_wisata": nama,
                "latitude": location.latitude,
                "longitude": location.longitude,
                "alamat": location.address,
                "provinsi": addr.get('state', ''),
                "kota_kabupaten": addr.get('city', '') or addr.get('county', '') or addr.get('region', '')
            })
            print(f"✓ Ditemukan: {nama}")
        else:
            results.append({
                "nama_wisata": nama,
                "latitude": None,
                "longitude": None,
                "alamat": "Not Found",
                "provinsi": "",
                "kota_kabupaten": ""
            })
            print(f"✗ Tidak ditemukan: {nama}")
    except Exception as e:
        results.append({
            "nama_wisata": nama,
            "latitude": None,
            "longitude": None,
            "alamat": f"Error: {e}",
            "provinsi": "",
            "kota_kabupaten": ""
        })
        print(f"⚠️ Error: {nama} - {e}")
    time.sleep(1)

# Simpan ke CSV
df = pd.DataFrame(results)
df.to_csv("wisata_papua_pegunungan_with_mall.csv", index=False)
print("✅ Data wisata Papua Pegunungan berhasil disimpan ke 'wisata_papua_pegunungan_with_mall.csv'")
# Out:
# ✗ Tidak ditemukan: Danau Tiga Ribu
# ✗ Tidak ditemukan: Gunung Carstensz
# ✗ Tidak ditemukan: Air Terjun Wamena
# ✗ Tidak ditemukan: Gunung Trikora
# ✗ Tidak ditemukan: Pantai Laut Mamberamo
# ✗ Tidak ditemukan: Taman Nasional Wasur
# ✓ Ditemukan: Gunung Puncak Jaya
# ✗ Tidak ditemukan: Kampung Adat Papua Pegunungan
# ✗ Tidak ditemukan: Pantai Teluk Cendrawasih
# ✗ Tidak ditemukan: Pantai Wamena
# ✗ Tidak ditemukan: Pantai Jayapura
# ✗ Tidak ditemukan: Air Terjun Sosiri
# ✗ Tidak ditemukan: Pantai Tanjung
# ✗ Tidak ditemukan: Pantai Rumeron
# ✗ Tidak ditemukan: Pantai Abar
# ✗ Tidak ditemukan: Pantai Waisai
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=Pantai+Lano%2C+Papua+Pegunungan%2C+Indonesia&format=json&limit=1&addressdetails=1
# ...

# %%
from geopy.geocoders import Nominatim
import pandas as pd
import time

# Daftar wisata Papua Barat Daya
wisata_papua_barat_daya_list = [
    "Gunung Arfak", "Pantai Sianapura", "Taman Laut Cenderawasih", "Pantai Merah", "Pantai Tanjung Kasuari",
    "Pulau Mansinam", "Pulau Biak", "Pantai Batu Mandi", "Danau Sentani", "Pantai Kosarek", "Taman Nasional Teluk Cenderawasih",
    "Pantai Siki", "Pantai Ambon", "Pantai Waisai", "Air Terjun Batanta", "Pantai Maratua", "Pantai Tanjung Wiri",
    "Pantai Kaimana", "Air Terjun Sosiri", "Pantai Bora", "Taman Laut Raja Ampat", "Kampung Wisata Waisai", "Kampung Adat Papua Barat Daya",
    "Gunung Misool", "Pantai Tobati", "Taman Laut Bira", "Air Terjun Lobo", "Pantai Sorong", "Pantai Amban",
    "Gunung Waigeo", "Gunung Tambrauw", "Pantai Abar", "Pantai Rees", "Pulau Umur", "Pantai Wera", "Pantai Yendidori",
    "Air Terjun Waisai", "Pantai Tablanusu", "Kampung Tradisional Waigeo", "Pantai Berau", "Pantai Maruni",
    "Pantai Salawati", "Pantai Yapen", "Pantai Mamberamo", "Taman Laut Raja Ampat", "Pantai Longgo", "Pantai Kaimana"
]

# Inisialisasi geolocator
geolocator = Nominatim(user_agent="wisata_geocoder_papua_barat_daya")
results = []

# Proses geocoding
for nama in wisata_papua_barat_daya_list:
    try:
        query = f"{nama}, Papua Barat Daya, Indonesia"
        location = geolocator.geocode(query, exactly_one=True, addressdetails=True)
        if location:
            addr = location.raw.get('address', {})
            results.append({
                "nama_wisata": nama,
                "latitude": location.latitude,
                "longitude": location.longitude,
                "alamat": location.address,
                "provinsi": addr.get('state', ''),
                "kota_kabupaten": addr.get('city', '') or addr.get('county', '') or addr.get('region', '')
            })
            print(f"✓ Ditemukan: {nama}")
        else:
            results.append({
                "nama_wisata": nama,
                "latitude": None,
                "longitude": None,
                "alamat": "Not Found",
                "provinsi": "",
                "kota_kabupaten": ""
            })
            print(f"✗ Tidak ditemukan: {nama}")
    except Exception as e:
        results.append({
            "nama_wisata": nama,
            "latitude": None,
            "longitude": None,
            "alamat": f"Error: {e}",
            "provinsi": "",
            "kota_kabupaten": ""
        })
        print(f"⚠️ Error: {nama} - {e}")
    time.sleep(1)

# Simpan ke CSV
df = pd.DataFrame(results)
df.to_csv("wisata_papua_barat_daya_with_mall.csv", index=False)
print("✅ Data wisata Papua Barat Daya berhasil disimpan ke 'wisata_papua_barat_daya_with_mall.csv'")
# Out:
# ✓ Ditemukan: Gunung Arfak
# ✗ Tidak ditemukan: Pantai Sianapura
# ✗ Tidak ditemukan: Taman Laut Cenderawasih
# ✗ Tidak ditemukan: Pantai Merah
# ✗ Tidak ditemukan: Pantai Tanjung Kasuari
# ✗ Tidak ditemukan: Pulau Mansinam
# ✗ Tidak ditemukan: Pulau Biak
# ✗ Tidak ditemukan: Pantai Batu Mandi
# ✓ Ditemukan: Danau Sentani
# ✗ Tidak ditemukan: Pantai Kosarek
# ✗ Tidak ditemukan: Taman Nasional Teluk Cenderawasih
# ✗ Tidak ditemukan: Pantai Siki
# ✗ Tidak ditemukan: Pantai Ambon
# ✓ Ditemukan: Pantai Waisai
# ✗ Tidak ditemukan: Air Terjun Batanta
# ✗ Tidak ditemukan: Pantai Maratua
# ✗ Tidak ditemukan: Pantai Tanjung Wiri
# ✗ Tidak ditemukan: Pantai Kaimana
# ✗ Tidak ditemukan: Air Terjun Sosiri
# ✗ Tidak ditemukan: Pantai Bora
# ...

# %%
# prompt: gabungkan semua dataset

import pandas as pd
import os

# List of generated CSV files
csv_files = [
    "wisata_sumatera_selatan_geocoding.csv",
    "wisata_lampung_geocoding.csv",
    "wisata_bangka_belitung_geocoding.csv",
    "wisata_dki_jakarta_geocoding.csv",
    "wisata_jawa_barat_geocoding.csv",
    "wisata_jawa_tengah_geocoding.csv",
    "wisata_yogyakarta_geocoding.csv",
    "wisata_jawa_timur_geocoding.csv",
    "wisata_banten_geocoding.csv",
    "wisata_bali_geocoding.csv",
    "wisata_ntb_geocoding.csv",
    "wisata_ntt_geocoding.csv",
    "wisata_kalbar_geocoding.csv",
    "wisata_kalteng_geocoding.csv",
    "wisata_kaltim_geocoding.csv",
    "wisata_kaltara_geocoding.csv",
    "wisata_sulut_geocoding.csv",
    "wisata_gorontalo_geocoding.csv",
    "wisata_sulteng_with_mall.csv",
    "wisata_sulsel_with_mall.csv",
    "wisata_sultra_with_mall.csv",
    "wisata_sulbar_with_mall.csv",
    "wisata_maluku_with_mall.csv",
    "wisata_malut_with_mall.csv",
    "wisata_papua_barat_with_mall.csv",
    "wisata_papua_selatan_with_mall.csv",
    "wisata_papua_tengah_with_mall.csv",
    "wisata_papua_pegunungan_with_mall.csv",
    "wisata_papua_barat_daya_with_mall.csv"
]

# List to store individual DataFrames
all_dataframes = []

# Read each CSV file and append to the list
for file in csv_files:
    if os.path.exists(file):
        df = pd.read_csv(file)
        all_dataframes.append(df)
        print(f"✓ Membaca file: {file}")
    else:
        print(f"✗ File tidak ditemukan: {file}")

# Concatenate all DataFrames into a single DataFrame
if all_dataframes:
    combined_df = pd.concat(all_dataframes, ignore_index=True)

    # Remove duplicate rows based on 'nama_wisata' and 'provinsi'
    combined_df.drop_duplicates(subset=['nama_wisata', 'provinsi'], keep='first', inplace=True)

    # Save the combined DataFrame to a new CSV file
    combined_df.to_csv("wisata_nusantara.csv", index=False)
    print("\n✅ Semua data berhasil digabungkan dan disimpan ke 'combined_wisata_geocoding.csv'")
    print(f"Total data unik setelah penggabungan: {len(combined_df)}")
else:
    print("\n⚠️ Tidak ada file CSV yang ditemukan untuk digabungkan.")
# Out:
# ✓ Membaca file: wisata_sumatera_selatan_geocoding.csv
# ✓ Membaca file: wisata_lampung_geocoding.csv
# ✓ Membaca file: wisata_bangka_belitung_geocoding.csv
# ✓ Membaca file: wisata_dki_jakarta_geocoding.csv
# ✓ Membaca file: wisata_jawa_barat_geocoding.csv
# ✓ Membaca file: wisata_jawa_tengah_geocoding.csv
# ✓ Membaca file: wisata_yogyakarta_geocoding.csv
# ✓ Membaca file: wisata_jawa_timur_geocoding.csv
# ✓ Membaca file: wisata_banten_geocoding.csv
# ✓ Membaca file: wisata_bali_geocoding.csv
# ✓ Membaca file: wisata_ntb_geocoding.csv
# ✓ Membaca file: wisata_ntt_geocoding.csv
# ✓ Membaca file: wisata_kalbar_geocoding.csv
# ✓ Membaca file: wisata_kalteng_geocoding.csv
# ✓ Membaca file: wisata_kaltim_geocoding.csv
# ✓ Membaca file: wisata_kaltara_geocoding.csv
# ✓ Membaca file: wisata_sulut_geocoding.csv
# ✓ Membaca file: wisata_gorontalo_geocoding.csv
# ✓ Membaca file: wisata_sulteng_with_mall.csv
# ✓ Membaca file: wisata_sulsel_with_mall.csv
# ...
